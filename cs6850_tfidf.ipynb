# %% [markdown]
# # Import Packages

# %%
import glob
import pandas as pd
from tqdm import tqdm
from nltk.tokenize import RegexpTokenizer
import re
import networkx as nx
from scipy.stats import kendalltau
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import gensim
import joblib

# %% [markdown]
# # Processing Data

# %%
txts = glob.glob("C:/Users/yiwei/Downloads/wiki_data/*.txt")
titles = []
texts = []
for val in tqdm(txts):
    with open(val) as f:
        text = f.read()
        title = text[text.find('>') + 1:text.find('<', 2)]
        texts.append(text)
        titles.append(title)
# Out:
# 100%|██████████| 40001/40001 [01:12<00:00, 552.31it/s]

# %%
corpus = pd.DataFrame({'title': titles, 'text': texts})

# %%
corpus.head()
# Out:
#        title                                               text
# 0      April  <title>April</title><text>{{monththisyear|4}} ...
# 1     August  <title>August</title><text>{{monththisyear|8}}...
# 2  Andouille  <title>Andouille</title><text>[[File:Andouille...
# 3   Calculus  <title>Calculus</title><text>{{More citations ...
# 4      Liter  <title>Liter</title><text>#REDIRECT [[Litre]] ...

# %%
corpus.to_csv('wiki_data.csv', index=False)

# %%
corpus = pd.read_csv('wiki_data.csv')

# %%
# because dataset is too big to handle with our resources (limitations for semantic graph), we subsample the data
# subset_corpus = corpus.sample(frac=0.25, random_state=42)
# subset_corpus.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Generating Semantic Graph from Dataset

# %%
CLEANR = re.compile('<.*?>') 

def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext

# %%
# removing punctuation
tokenizer = RegexpTokenizer(r'\w+')
to_tokenize = []
for sentence in tqdm(corpus['text']):
    to_tokenize.append(' '.join(tokenizer.tokenize(cleanhtml(sentence))))
# Out:
# 100%|██████████| 40001/40001 [00:03<00:00, 12688.81it/s]

# %%
idx_title_mapping = {idx: str(corpus['title'][idx]).lower() for idx in range(len(to_tokenize))}

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
def get_text_embedding(tokens, model):
    word_vectors = []
    for word in tokens:
        if word in model.key_to_index:  # Check if word is in the model's vocabulary
            word_vectors.append(model[word])
    if word_vectors:
        return np.mean(word_vectors, axis=0)
    else:
        return np.zeros(model.vector_size)  # Return zero vector if no word vectors

# Compute the embeddings for each document
text_embeddings = np.array([get_text_embedding(tokens, model) for tokens in tqdm(to_tokenize)])

# Calculate the cosine similarity matrix between the embeddings
cos_sim_matrix = cosine_similarity(text_embeddings)
# Out:
#   0%|          | 0/40001 [00:00<?, ?it/s]
# 100%|██████████| 40001/40001 [01:09<00:00, 576.52it/s]

# %%
joblib.dump(cos_sim_matrix, 'cos_sim_matrix_word2vec.pkl')
# Out:
# ['cos_sim_matrix_word2vec.pkl']

# %%
# Threshold for considering an edge (e.g., similarity > 0.1)
threshold = 0.1

# Create the graph without adding too many edges
SG = nx.Graph()

for i in tqdm(range(len(to_tokenize))):
    SG.add_node(i, content=(to_tokenize[i]))  # Add article as a node
    
    for j in range(i+1, len(to_tokenize)):
        similarity = cos_sim_matrix[i, j]
        
        if similarity > threshold:
            SG.add_edge(i, j, weight=similarity)

# After this, G will only contain edges with similarity above the threshold
# Out:
#   3%|▎         | 1314/40001 [01:57<57:34, 11.20it/s]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[17], line 14
#      11 similarity = cos_sim_matrix[i, j]
#      13 if similarity > threshold:
# ---> 14     SG.add_edge(i, j, weight=similarity)
#
# File c:\Users\yiwei\anaconda3\envs\3350\Lib\site-packages\networkx\classes\graph.py:964, in Graph.add_edge(self, u_of_edge, v_of_edge, **attr)
#     962 datadict = self._adj[u].get(v, self.edge_attr_dict_factory())
#     963 datadict.update(attr)
# --> 964 self._adj[u][v] = datadict
#     965 self._adj[v][u] = datadict
#     966 nx._clear_cache(self)
#
# MemoryError:

# %%
PR = nx.DiGraph()
pattern = r'\[\[(.*?)\]\]'
titles = corpus['title'].str.lower()
PR.add_nodes_from(titles)
for i in tqdm(range(len(corpus['title']))):
    txt = corpus['text'][i]
    references = re.findall(pattern, txt)
    for reference in references:
        if len(titles[titles == reference]) > 0:
            PR.add_edge(titles[i], reference.lower())

# %% [markdown]
# # OLD CODE

# %%
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import numpy as np

# Compute the TF-IDF matrix (sparse)
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(to_tokenize)  # articles is your list of article texts

# Calculate cosine similarity matrix (only for pairs with a non-zero similarity)
cos_sim_matrix = cosine_similarity(tfidf_matrix)
joblib.dump(cos_sim_matrix, 'cos_sim_matrix.pkl')
# Out:
# ['cos_sim_matrix.pkl']

# %%
# Threshold for considering an edge (e.g., similarity > 0.1)
threshold = 0.1

# Create the graph without adding too many edges
SG = nx.Graph()

for i in tqdm(range(len(to_tokenize))):
    SG.add_node(i, content=(to_tokenize[i]))  # Add article as a node
    
    for j in range(i+1, len(to_tokenize)):
        similarity = cos_sim_matrix[i, j]
        
        if similarity > threshold:
            SG.add_edge(i, j, weight=similarity)

# After this, G will only contain edges with similarity above the threshold
# Out:
# 100%|██████████| 10000/10000 [00:12<00:00, 816.42it/s]

# %% [markdown]
# ## Generating PageRank Graph from Dataset

# %%
# first graph generate under pretext of a "closed environment"
PRG = nx.DiGraph()
pattern = r'\[\[(.*?)\]\]'
titles = corpus['title'].str.lower()
PRG.add_nodes_from(titles)
for i in tqdm(range(len(corpus['title']))):
    txt = corpus['text'][i]
    references = re.findall(pattern, txt)
    for reference in references:
        if len(titles[titles == reference]) > 0:
            PRG.add_edge(titles[i], reference.lower())
# Out:
# 100%|██████████| 10000/10000 [02:29<00:00, 66.73it/s]

# %% [markdown]
# # Using Semantic Graph for PageRank

# %%
# using PageRank
pr_semantic = nx.pagerank(SG, weight='weight')
pr_semantic = {idx_title_mapping[idx]: pr_semantic[idx] for idx in pr_semantic}

# %%
pr_semantic
# Out:
# {'iliad': 0.00031967378294590996,
#  'natural history': 0.0003456240121572913,
#  '1955': 0.00045061863185688784,
#  'bismarck (ship)': 0.00025148840656744384,
#  'ohio river': 9.451045898665043e-05,
#  'chief executive officer': 0.00023595867199984274,
#  'grass': 0.0001627866145495946,
#  'sergei prokofiev': 0.0006131843035978945,
#  'hajj': 0.0003835970223377861,
#  'balfour declaration of 1917': 0.00015271642221831403,
#  '1258': 0.00038659879413410184,
#  'chin': 0.00023564875791872299,
#  'main': 0.00039480411219003906,
#  'developmental biology': 0.0002462628963525054,
#  'eagle': 0.0001260798149650851,
#  'nia': 9.52026753173541e-05,
#  'benzene': 0.00011253710870711277,
#  '1918': 0.0002837818602838858,
#  'amaterasu': 0.00023931685076485862,
#  '50': 0.00011767090300168684,
#  'arturo toscanini': 0.00043106114035413906,
#  'castle': 0.00030588189562339764,
#  'woodwind instrument': 0.00041191829985669974,
#  'foot': 0.0002084280854242049,
#  'universe': 0.0007179868229040932,
#  'yankee stadium (1923)': 0.00021375407823990883,
#  'potsdam': 0.00018343674079000332,
#  'micropachycephalosaurus': 8.376548669024302e-05,
#  'california institute of technology': 0.0001851136515707554,
#  'burundi': 0.00014662019103897338,
#  'ebola virus': 0.0002483173763732398,
#  'spectrometer': 7.97447350068444e-05,
#  'frankfurt': 0.00023780795000622653,
#  'biosphere': 0.00013085167870335935,
#  'apostle': 0.0001538265021429994,
#  'oligarchy': 0.00013849901806943586,
#  'emperor go-sanj': 0.00011737350160056454,
#  'castration': 0.000283768549537165,
#  'k': 0.0002054707005165602,
#  'harmony': 0.00010773730560175956,
#  'anglesey': 7.96556872017201e-05,
#  'urine': 0.00030615669205951557,
#  'elas pia province': 0.00019087262149864264,
#  'metaphysics': 0.00028684951204573154,
#  'granite': 8.762299253489712e-05,
#  'chastity belt': 6.818590727967394e-05,
#  'masaccio': 0.0006917769634897493,
#  '1262': 0.0002290814950096754,
#  'mariana islands': 0.00027634306297190196,
#  'moksha': 0.00026889007737792187,
#  'bow (music)': 0.0004044740026584712,
#  'real-time strategy': 0.000245872893374201,
#  'barnes & noble': 0.0001800720948714044,
#  'prince (musician)': 0.0002733735242937806,
#  'homophony': 0.00020668155527654565,
#  'bartolomeu dias': 0.00011103661266458393,
#  'royal palace of madrid': 0.0001806864617366424,
#  'virgil': 0.00013253835128233284,
#  'boer': 0.00026361021438200955,
#  'star': 0.0005136107606019626,
#  "bishop's stortford": 0.0004070121409398246,
#  'associated board of the royal schools of music': 0.0004555681970271771,
#  'safety curtain': 9.276930004337753e-05,
#  'whigs': 0.0003087071930678663,
#  'unix': 0.00010601751495184901,
#  'astronomer royal': 0.00026214229450205765,
#  'metamorphosis': 0.00024598222827565,
#  'cross-country race': 0.0001564871503420832,
#  'sneeze': 8.603750123913947e-05,
#  'december 31': 0.0004131103633557354,
#  'homestar runner': 0.00013431949254693684,
#  'springfield, illinois': 0.00012382992244643708,
#  'eye (cyclone)': 0.0002592881891186646,
#  'fu xiancai': 0.00019006838949592702,
#  'nearctic': 0.00010287628191983301,
#  'eukaryote': 0.0005676242392394431,
#  'thoroughbred': 0.0003740746350942089,
#  'stonemasonry': 8.733839193956495e-05,
#  'diabetes insipidus': 8.407365823318209e-05,
#  'parliament of england': 0.0006227765750521765,
#  'renewable energy': 0.00017113993163556332,
#  'wikipedia:blocks and bans': 0.0002099111607810696,
#  'u2 (band)': 0.0001616023838826139,
#  'martial arts': 0.0003627757142124271,
#  'esztergom': 0.00036591520281836147,
#  'chloroplast': 0.00012026298984035288,
#  'mythology': 0.0004025655068071667,
#  'psychedelic rock': 0.0001730778479831465,
#  '1765': 0.00013576689477520947,
#  'jordan river': 0.0003501714958092316,
#  'incisor': 0.00010582974469925889,
#  'manure': 0.00013137416896346073,
#  'cromwell current': 0.0001543014941813138,
#  'gandalf': 0.00018021976777024264,
#  '1979': 0.0005218258606369908,
#  'snooker': 0.00014788446445085252,
#  'kura-araxes culture': 7.568357217317158e-05,
#  'cyberstalking': 0.00012145961292113205,
#  'rugby league': 0.000227415804546285,
#  'abu bakr': 0.00011051650452321083,
#  'deal or no deal': 0.00035121155040524177,
#  'booing': 0.0001340900680305812,
#  'necktie': 8.89357955128124e-05,
#  'hungarian language': 0.0002439389152836668,
#  'lord voldemort': 0.00022448111314797204,
#  'yellow river': 0.0002229752021622193,
#  'channel tunnel': 0.00016504806273277662,
#  'pope': 0.00021132240551047408,
#  'file system': 0.0003309586742602447,
#  'the seven wonders of the world': 9.53378446470127e-05,
#  'robbie williams': 0.00031976805850644503,
#  'legion of net. heroes': 8.231020620809761e-05,
#  '1529': 0.00024275302455613782,
#  'ecozone': 0.0002514429450318426,
#  'sivaya subramuniyaswami': 7.350915959643031e-05,
#  'crookes': 0.00013378863888438493,
#  'protagonist': 0.00032699010858716165,
#  'spleen': 0.00015255862803842594,
#  'saint peter': 0.0004077001384938231,
#  'sprain': 0.00019335692457507847,
#  'carl sagan': 0.00016778190877249482,
#  'february 7': 0.0003391592265076397,
#  'ancient egypt': 0.0007584194166103908,
#  'offside rule': 0.0002040135311506263,
#  'russian revolution': 0.0006582883330802213,
#  'alcoholism': 0.00025891676471007216,
#  'elementary algebra': 0.00021809046429210983,
#  'israel': 0.0006103067448655563,
#  'co-operative party': 0.00026917465538997754,
#  'alchemy': 0.00018219594600537285,
#  'ananke group': 9.379900941749765e-05,
#  'heat engine': 0.00024830415213850294,
#  'lawsuit': 0.0002666476836053782,
#  'kullervo': 4.38893118665569e-05,
#  'solomon': 0.00014007755696743512,
#  'florida keys': 0.00013844595069622021,
#  "the pilgrim's progress": 0.0008059726184773038,
#  'council of the european union': 0.00044762561863329455,
#  'captain of kpenick': 0.0004054766749312043,
#  'audition': 0.0002456493893837488,
#  'armenian catholic church': 0.0003201463470243679,
#  'black sabbath': 0.00018422412506200484,
#  'human digestive system': 0.00025727889803160833,
#  'spectral line': 0.00021869372331783854,
#  'volleyball': 0.0006378090949263669,
#  'imperialism': 0.00014866967897820996,
#  'photography': 0.00033873608246284766,
#  'syphilis': 0.0001387047124727339,
#  'book of job': 0.00015316266387417767,
#  'category:1860s': 0.00017157499537477636,
#  'orange (fruit)': 0.00027766233128926504,
#  'general relativity': 2.6845218438775746e-05,
#  'pennines': 0.00020418317253856732,
#  'infrastructure': 0.00012618340954154478,
#  'santa cruz river': 0.00013410078639732305,
#  'hillary clinton': 0.00023758758805606225,
#  "ma'at": 0.0005121300755510916,
#  'service (economics)': 0.00035761629549707863,
#  'disappearance of madeleine mccann': 0.00011057390418607994,
#  'matterhorn': 7.432739631034065e-05,
#  'die walkre': 0.00032529306592708236,
#  'canadian football': 0.00028033904577908387,
#  'british indian ocean territory': 0.0003432746753918786,
#  'magnet': 9.711560461039085e-05,
#  'babylon': 0.0005996472582626243,
#  'ohana': 0.0004037387435021609,
#  'ishy bilady': 0.000148381331287396,
#  'florida panhandle': 0.00018833142686875356,
#  'ishmael': 0.0001178147472648048,
#  'maximilien de robespierre': 0.00010465493531184999,
#  'nile': 0.00017565910607534831,
#  'category:600s bc deaths': 0.00014288312479532637,
#  'jurisdiction': 6.514701662283983e-05,
#  'virtues of harmony': 0.0001449301869635682,
#  '1707': 0.00017373063675825323,
#  'brown dwarf': 0.00028357219939140085,
#  'lira da braccio': 0.00016758758524920822,
#  'history of japan': 0.0008588518714093459,
#  'wrocaw': 9.146707693829773e-05,
#  'olivia newton-john': 0.00020565554722860584,
#  'ming dynasty': 0.0004619649580697633,
#  'malaysia': 0.0003357332927744206,
#  'category:1590s': 0.00016215107743854302,
#  'colossus of rhodes': 0.0003102859394800599,
#  'hand': 0.00017028993249259855,
#  'aesop': 5.275301527524532e-05,
#  'abdullah calan': 0.00046104542069699605,
#  'battle of princeton': 0.0002232151951678291,
#  'gram (mythology)': 0.00018200886673210983,
#  '2004 redfern riots': 0.00015800715024156717,
#  'ian fleming': 0.00010123445599551794,
#  'aquaculture': 0.0001318470348450133,
#  'electric guitar': 0.00034612053277597254,
#  'great depression': 0.0005108518077349622,
#  'yoga': 9.095640423647092e-05,
#  'tissue': 0.00019130651104480288,
#  'windsurfing': 0.00018717906983617142,
#  'mercury (planet)': 0.00027105057470320267,
#  'huo qubing': 8.690174358264603e-05,
#  'aether': 0.00013283415382017879,
#  'william blake': 4.9873875119311166e-05,
#  'fictional character': 0.00040288434619860494,
#  'franz kafka': 0.0002635475227113046,
#  'breinigerberg': 0.00016462069633198947,
#  'radiation pressure': 0.00015405405691544028,
#  'luciano pavarotti': 0.0004210115534389662,
#  'd-day (military term)': 0.00033898959673171926,
#  'tibet': 0.00032076198513071694,
#  'four noble truths': 0.00020046829320241136,
#  'olympia, washington': 0.0002682497937056646,
#  'exoskeleton': 8.074378244994968e-05,
#  'sundial': 8.734322980442977e-05,
#  'war communism': 0.00020195824125372868,
#  'lancelot': 0.00022179296201701426,
#  'royal society for the prevention of cruelty to animals': 0.00014991671440344975,
#  'acts of supremacy': 0.00045185992761175047,
#  'berlin wall': 0.0005353789207987741,
#  'clothing': 0.00020179894535617842,
#  'fishing': 0.00022298459758457215,
#  'united states marine corps': 0.00021425107530763547,
#  'supernova': 0.0003794772387437301,
#  'moss': 0.00015872177898043152,
#  'integral': 0.00021726333158390593,
#  'house of wettin': 0.0001742850885039704,
#  'anarchy in the u.k.': 0.00014200013465413136,
#  'science': 0.0006108930446166119,
#  'nectar': 0.00013211070069013735,
#  'aramaic language': 0.00013362614031202694,
#  'mechanistic paradigm': 0.0003068323889128633,
#  'demeter': 0.00011652744629546597,
#  'vahan totovents': 8.527361015354657e-05,
#  'shrek (movie)': 0.0001707655285854394,
#  'meaning of life': 0.000302966196027111,
#  'density': 0.0002401359934261143,
#  'march 3': 0.0003652787572445159,
#  'flying tigers': 0.0001991099816803792,
#  'american samoa': 0.0001392958384234528,
#  'claude debussy': 0.0004960541622843659,
#  'aqua regia': 0.0003023867603996357,
#  'stem (music)': 0.0002903649669754756,
#  'supply': 0.00031291693199681376,
#  'telugu': 0.0002667423200990199,
#  'the nutcracker': 0.00048795578772918997,
#  'pirates of the caribbean: the curse of the black pearl': 0.00032878518429080707,
#  'csar franck': 0.0002899161784917293,
#  'republic of the congo': 0.00028743542220772966,
#  'beyond (album)': 0.00019290989820411133,
#  'german bundesrat': 0.00017530218288750523,
#  'castile': 0.00010262325237546133,
#  'finger': 9.199130956366057e-05,
#  'mount vesuvius': 0.00037517136524589445,
#  'sense and sensibility': 0.00021668333027101592,
#  'toronto': 0.00020720603897848833,
#  '1302': 0.00019484817319984709,
#  'resurrection': 0.00037491541223340455,
#  'annapolis, maryland': 0.0001929768356607141,
#  '1976': 0.00025512056004607745,
#  'dysphemism': 5.3883404945602745e-05,
#  'time travel': 0.0003350713164055745,
#  'colorimeter': 0.000242120451210004,
#  '1996': 0.0005315747656653166,
#  'aymara people': 0.00011484648524489017,
#  'march 15': 0.0004721780095622952,
#  'obelus': 9.053137474285572e-05,
#  'bird': 0.0006026835979435654,
#  '1929': 0.00016844221781696367,
#  'evaporation': 0.0001058610315988779,
#  'fall/liberation of saigon': 0.00010628201213284074,
#  'bogot': 0.00021440443302013788,
#  'homosexuality': 0.0005237030553895203,
#  'criticism': 0.00013644760793055466,
#  'carl nielsen': 0.00034171433140356265,
#  'mobile bay': 0.00020938687390703996,
#  'trialeti culture': 0.00016783812117722699,
#  'may 15': 0.0004388477430290336,
#  'religious society of friends': 0.0004201755522514999,
#  'ethiopia': 0.00027366172864922073,
#  'camille saint-sans': 0.00042024748886368684,
#  'northern hemisphere': 0.00017895080957055273,
#  'windsor castle': 0.0001487903732929601,
#  'uk independence party': 0.00013105402896217556,
#  'footwear': 0.0001621867165808062,
#  'december 9': 0.000319679870099279,
#  'deformation': 0.00010803048412906414,
#  'sally beamish': 0.0001326007684126414,
#  'blues': 0.000229542750805044,
#  'may 3': 0.0004490440460508694,
#  'chemistry': 0.00041056137028031204,
#  'literacy': 0.0001848243917496352,
#  'cone': 0.00029643488950751397,
#  'vienna': 0.00047481945660712876,
#  '1391': 0.00015634243488483739,
#  'organization for security and co-operation in europe': 0.00010287240300041483,
#  'skin': 0.00014482681789913085,
#  'the lord of the rings (movie series)': 0.0005583704355611991,
#  'exalead': 0.00014826323909657315,
#  'asteroid belt': 0.0003179500248161144,
#  'modest mussorgsky': 0.00036351261415522724,
#  'world youth day': 0.00019468313030714042,
#  'ccuta': 0.0003356739080242124,
#  'amish': 0.00017536403906061155,
#  'chapter (books)': 0.00020338023503344797,
#  'thermodynamic potential': 0.00013307156996449562,
#  'try': 0.00022854045075645655,
#  'human migration': 0.0002856393888146814,
#  'aspirator': 0.0002450931631829244,
#  'venus (mythology)': 8.804899665812137e-05,
#  'belaying': 8.568495195014847e-05,
#  'english interregnum': 0.00026460985929758883,
#  'aryan': 0.00039700524997338365,
#  'kumquat': 0.00011038192448998305,
#  'the left party.pds': 0.000391248161854596,
#  'alexander graham bell': 0.000566499250034029,
#  'aquitaine': 0.00017454734306476528,
#  'hero': 0.00020641598223623294,
#  'geometry': 0.00018563923646614699,
#  '2000s (decade)': 0.0004735905744612446,
#  '14': 0.00020037999947265984,
#  'talent (measurement)': 0.0003791542882722678,
#  'hassan nasrallah': 0.00014069909171753126,
#  '1250': 0.00023023691959707545,
#  'scrabble': 0.0005023420599509975,
#  'national hurricane center': 0.00013962198700756355,
#  'pure pwnage': 0.0003572292661905734,
#  'nairi': 0.0001227880622949461,
#  'durham': 0.0002493532878397856,
#  'juan crisstomo de arriaga': 0.00014283642834415913,
#  'southern europe': 0.00022641972795593888,
#  'set': 0.00035894211383599007,
#  'november 1': 0.0005560275821051014,
#  'lascelles abercrombie': 6.992909495646388e-05,
#  'viennese waltz': 0.00036517222957047014,
#  'tropical storm alpha (2005)': 0.0001604423459496109,
#  '930s': 0.00040138902761057544,
#  'religion of ancient egypt': 0.0007532530158887831,
#  'trajan': 0.00013092294621813277,
#  'cowboy': 0.0001892174987452184,
#  'banknote': 0.0002510489376367319,
#  'winston churchill': 0.0005454625080657593,
#  'kabir': 7.922722323203951e-05,
#  'category:1630s': 0.00013675213044065694,
#  'wikipedia:standard messages': 0.00018999836094916265,
#  'octopus': 0.0004040377672560521,
#  'royal air force': 7.811435572577989e-05,
#  'columbian exchange': 0.000367299486148062,
#  'elastic modulus': 0.00010089017208311313,
#  'pride and prejudice': 0.00011527596742531805,
#  'old age': 0.0001831270191916363,
#  'anastas mikoyan': 0.00014234438245211875,
#  'minutes to midnight': 0.00015037983477020914,
#  '1306': 0.00013660817693143153,
#  'firefly (tv series)': 0.0005379109075974558,
#  'royal court': 0.0001430895884807362,
#  'amiri baraka': 8.991850495463675e-05,
#  'song cycle': 0.00013425140406796293,
#  'emma goldman': 0.00020145720873435087,
#  'theorem': 0.0001638308746858044,
#  'venice': 0.0004989261262692696,
#  'henry i of england': 0.00019198722871371682,
#  'room temperature': 0.00018644902629051189,
#  'polar cyclone': 0.0002839595216785399,
#  'cerberus': 4.955375969074952e-05,
#  'category:1990s': 0.00014433910874000688,
#  'november 29': 0.0003339872020436354,
#  'frenulum': 0.0002139342109135458,
#  'composite material': 0.00010873397671859823,
#  'eastern christianity': 0.00013105638767491856,
#  'richard iii of england': 0.0006031997360757172,
#  'glorious revolution': 0.0006902191382252387,
#  'viriato clemente da cruz': 0.0002781770723303462,
#  'tribute': 0.00030342544759351663,
#  'eris': 0.00013637921796728593,
#  'chiinu': 0.000694376939212147,
#  'by-election': 0.00014283882760931718,
#  'lord of the rings': 8.283487638602652e-05,
#  'british columbia': 0.0005907330738995965,
#  'escape the fate': 0.00013964561903459776,
#  'ostinato': 0.00012775083706657853,
#  'indo-european languages': 0.00016540986413238307,
#  'chuck (tv series)': 0.00012350391067145213,
#  'accra': 0.0001102329371247227,
#  'albert camus': 0.00011886801226868696,
#  'tambourin': 0.00012668155876549773,
#  'struthiomimus': 7.618830682254556e-05,
#  'cerebrum': 0.00034589011750780135,
#  'manfred von richthofen': 0.0001423873873682757,
#  'trades union': 0.0005670416839720187,
#  'genetic drift': 0.00020648746799853399,
#  'letitia christian tyler': 0.0001416358228566565,
#  'julius streicher': 0.00023623919034879254,
#  'ferdinand magellan': 0.00017170352274520999,
#  'conakry': 9.307351766837165e-05,
#  'pharmacology': 0.0003754144743556739,
#  'olive (fruit)': 0.00011154000175227985,
#  'april 16': 0.0003536327420202982,
#  'nyx': 0.00014441448935789016,
#  'shepherd': 0.0002596080188958711,
#  'the seasons (haydn)': 0.0006197845900698959,
#  'moldovan language': 0.0001743487669784472,
#  '1st century': 0.0006071710068848757,
#  'wilsonian armenia': 0.00013623394228635475,
#  'psychoanalysis': 0.00023597236223784075,
#  'economy of india': 0.0002075567690396715,
#  'demographics of nicaragua': 0.0005380596425691864,
#  'legend': 0.00013432730562654843,
#  'greek myth': 4.725508900345434e-05,
#  'wessex': 0.00014613528975877812,
#  'emmy award': 0.00011012609076745006,
#  'empty string': 0.00010613011731801201,
#  'jury nullification': 0.00018077096110017145,
#  'fixed-wing aircraft': 0.00023809383861162704,
#  'nation': 0.00036583672549142515,
#  'crop rotation': 9.376966529000133e-05,
#  '1370': 0.00019754724669956235,
#  'samuel adams': 0.00022485888533449097,
#  'may': 0.0003688928397912381,
#  'mao asada': 0.0002224161046860006,
#  'care bears movie ii: a new generation': 0.00013224923744379198,
#  'man': 0.00014741082391868501,
#  'larva': 0.00027537397131224616,
#  '940s': 0.0002623987336882039,
#  'sirens (movie)': 0.00014890460039966187,
#  'aries': 9.145385254066481e-05,
#  'secret intelligence service': 0.00010715091840315034,
#  'kobayr monastery': 0.0002301927789463697,
#  'genetic engineering': 0.00015022591238537253,
#  'pronoun': 0.00022038836523389287,
#  'october 27': 0.00040751981943878686,
#  'duccio': 0.0004388078300626914,
#  'david ii of scotland': 0.00018209520384199622,
#  'crook of devon': 0.00014882034165558945,
#  'april 8': 0.0004219001171079282,
#  'january 30': 0.0005196941819874127,
#  'golden retriever': 0.00017464228659792118,
#  'nobel prize': 0.00029531132899942046,
#  'robert e. lee': 0.0003155110731957494,
#  'history of taiwan': 0.00036548435787812396,
#  'youssef rzouga': 0.00022383904623804162,
#  'social democrat hunchakian party': 0.00034353967740482913,
#  'uncle': 0.00013082049654947677,
#  'category:1480s': 0.00012194684923848769,
#  'japanese dragon': 0.00028986220005738927,
#  'wikipedia:deletion policy': 0.0003226332366785665,
#  'yuri gagarin': 0.00020053535342033423,
#  'pope paul vi': 0.00012189503008330093,
#  'trial': 0.0002707302022230546,
#  'buddhism': 0.0003976049747140457,
#  'five solas': 0.00011043970687448193,
#  'oil well': 0.00015620744287218877,
#  'tamahagane': 0.00017061409607249778,
#  'united states dollar': 0.0005826516503317384,
#  'category:american revolutionary war': 0.0002496179792849688,
#  'the birth of venus (botticelli)': 6.9411945677768e-05,
#  'template': 0.0005663453914806157,
#  'nature': 0.00029125166273492414,
#  'circumcision': 0.0003096707040108265,
#  'february 17': 0.0003540750185450513,
#  'shushi massacres': 0.0003045451057075018,
#  '1206': 0.00012176858706853052,
#  'european parliament': 0.0005213647156908962,
#  'january 7': 0.0004234439184893675,
#  'heaven': 0.0003982119717982897,
#  'hindu gods': 0.0003689489386905888,
#  'nat king cole': 0.0002824138114420853,
#  'neotropic': 0.00033327908777585415,
#  'language': 0.0005705921686146581,
#  'hard and soft drugs': 0.00019016133033576853,
#  'battle': 0.00012734176944662008,
#  'n-dubz': 0.00013644515376459672,
#  'peridot': 8.26055209688588e-05,
#  'coelurosauria': 0.00020478346319497448,
#  'spamming': 0.00016982484309494198,
#  'object-oriented programming': 0.00014447066514633954,
#  "breakfast at tiffany's": 0.00018486672969575564,
#  '1825': 0.00025188218620085116,
#  '1780': 0.0001976898063797921,
#  'november 8': 0.0005368743495120057,
#  'microscope': 0.00010782243803781468,
#  '1782': 0.0004417916951148056,
#  'manhattan': 0.0009456376255668088,
#  "everybody's changing": 0.00015054992234288562,
#  'viol': 0.00028534010638902875,
#  'nobility': 0.00014682652241644403,
#  'bikini': 0.00018638215001524756,
#  'province of alicante': 0.0001224133567210914,
#  'purgatory': 0.00010420342067895854,
#  'emperor of japan': 0.0005505031678545841,
#  'statistical hypothesis test': 0.00011494002473877706,
#  'space shuttle': 0.00012924533437068576,
#  'iwasawa theory': 0.00025388416132143517,
#  'nix (moon)': 8.983409523449299e-05,
#  'kurt schumacher': 0.0002829070345148729,
#  'battle of yorktown (1781)': 0.0004295585479121987,
#  'sex organ': 0.0005333424263803324,
#  'social sciences': 0.00012865404070285078,
#  'northamptonshire': 0.00019198982806022225,
#  'sermon': 0.00013134780968867912,
#  'al ain': 0.0004708924416068474,
#  '1190s': 0.0001761510252380326,
#  'category:1560s': 0.00014487841114333162,
#  'category:1350s': 0.00013681706140925161,
#  '1774': 0.00021276952891899085,
#  'brazzaville': 0.00017443181065639654,
#  'david souter': 0.00013269148816974976,
#  'archaeopteryx': 9.928177626768804e-05,
#  'function (mathematics)': 0.00039389759676326824,
#  'garage rock': 0.00016381134289131873,
#  'munich': 0.00020012859812750617,
#  'hogwarts': 0.00032527576784643306,
#  'phoenix, arizona': 0.00026605833578721846,
#  'rocky': 0.0001205974849503272,
#  'sega genesis': 0.00019782480155948424,
#  'ancient armenia': 0.00023610038559275444,
#  'astrophysics': 0.00032356425705496394,
#  'category:1950s': 0.00022914626581654077,
#  'vulnerability': 7.652594862796142e-05,
#  'march 11': 0.0003641410251966404,
#  'vigds finnbogadttir': 0.00011278478068225217,
#  'november 18': 0.00046051588499675794,
#  'foreskin': 0.00022532222768757655,
#  'troodon': 0.0001243369016512122,
#  'sports car': 0.00011325592337547637,
#  'auvergne': 0.00013341503800659346,
#  'charles darwin': 0.0007437432251297984,
#  'bethlehem housing authority': 0.00043750466309461797,
#  'pierre trudeau': 0.00014916966692871426,
#  'category:100s bc births': 0.0001591505721061339,
#  'spectrum': 0.00022393742426792546,
#  'november 14': 0.0003410506819969619,
#  'aragon': 0.0002868749328195686,
#  'boxing': 0.00010409953452092488,
#  'edsel': 0.000186095434566218,
#  'european sprat': 7.35768954027343e-05,
#  'peasant': 0.00020994786175206043,
#  'arthur wellesley, 1st duke of wellington': 0.00020366573190166922,
#  'ethnic group': 0.00025590038685509775,
#  '5 bc': 0.00016845240756050114,
#  'butterfield, missouri': 0.00036037008136519707,
#  'house of representatives': 0.0002160168862120182,
#  'psyche (psychology)': 0.00012433664664778847,
#  'movie producer': 0.000286793185630941,
#  'category:1840s': 0.0001726886465444718,
#  'tunicate': 0.00015238011903476634,
#  'wikipedia:criteria for adminship': 0.0003527885035158373,
#  'category:12th century': 0.0001695132744585932,
#  'fortaleza': 0.0002533001631407784,
#  'irish people': 0.00019767913960674503,
#  'category:230s': 0.00012759300713019288,
#  'poverty in india': 0.0002943711199402614,
#  'bloemfontein': 0.0001877053199255391,
#  'gppingen': 0.00021455294392136418,
#  '1800': 0.00044364074529508436,
#  'adolf hitler': 0.00037744892441039844,
#  'video relay service': 7.842945507451693e-05,
#  'dog': 0.0001553873749479998,
#  'instant messaging': 0.00040194466983337486,
#  'tony curtis': 0.0003780369476495596,
#  'october 14': 0.0006554369589072759,
#  'wikipedia:voting': 0.00015656585401867439,
#  'jerry lewis': 0.00017861774180011835,
#  'edward vii': 0.00046590874235062337,
#  'uss arizona (bb-39)': 0.0001437381952403174,
#  'template:flagiconb/doc': 0.0002798519615789396,
#  'investiture controversy': 0.00033904561890669993,
#  'giovanni gabrieli': 0.0001084597103338219,
#  'rio de janeiro': 0.00013846153227064896,
#  'scorpion': 0.0002642901322364144,
#  'exponentiation': 0.0003285684886877971,
#  'folk music': 0.0003036009450830045,
#  'category:320s': 0.0001344868673489534,
#  'robert burns': 4.40807005361326e-05,
#  'if': 4.403004763731261e-05,
#  'operating system': 3.1793115621424434e-05,
#  'freyr': 9.999244046011933e-05,
#  'deadliest catch': 0.00021411856930835722,
#  'great circle': 0.0001293575105864925,
#  'william wallace': 0.0002656778316458572,
#  'interregnum': 0.0002195880152750048,
#  'chinese characters': 0.00033825349143178177,
#  'antonie van leeuwenhoek': 0.0001269444195347584,
#  'psychology': 0.00015822763825155568,
#  'sawmill': 0.00039438634669461127,
#  'eddy merckx': 0.00017782967241078738,
#  'perseus': 0.000202826214681593,
#  'ssirum': 0.0003460875662873678,
#  'enabling act': 0.00034135896649689255,
#  'gefjun': 5.597220437004295e-05,
#  'data mining': 0.00038517565548122927,
#  'motherboard': 0.00032040624291456517,
#  'george harrison': 0.00029538325561490514,
#  'lutheranism': 0.0003221456051984843,
#  'army': 0.0005525830018133848,
#  'asgard': 0.00025071120877431536,
#  'national party of australia': 0.00013971648862213994,
#  'quito': 0.0005162501156870774,
#  'manitoba': 0.00019087944917349744,
#  'narcolepsy': 9.579925301341004e-05,
#  'october 21': 0.0005096850708868686,
#  '1030': 0.0004116019287069385,
#  'sudan': 0.00012203035028936657,
#  '1275': 0.0004460924622840283,
#  'monophthong': 6.405163571746737e-05,
#  'ted bundy': 0.0002127069381098809,
#  'liberia': 0.00022587545172842623,
#  'baltic states': 0.0003279824537138741,
#  'sentence': 0.00023442423524303946,
#  'alexander scriabin': 0.0002747928476282163,
#  'category:60s': 0.0001717667688328478,
#  'observation': 0.00045695706914826434,
#  'friendship': 0.0001797658920273671,
#  'thucydides': 1.8046214916785882e-05,
#  'monty hall problem': 0.0001800750139147534,
#  'primary source': 5.6271076463117966e-05,
#  'british antarctic territory': 0.00023618191208427662,
#  'argos': 0.00013585832018928103,
#  'category:1st century': 0.0002097040047761151,
#  'argonauta': 0.0003536500675101775,
#  'census': 0.0001418949717182482,
#  'april 27': 0.00034275103259905006,
#  'cholera': 0.00011110077702792347,
#  'hippopotamus': 0.0002452559060827735,
#  'home run': 0.00015423314068192985,
#  'eye of horus': 0.00023725317347970964,
#  'vichy france': 0.0001581757242931311,
#  'humanism': 0.00034873971826628655,
#  'sexual abstinence': 0.00010854879683112992,
#  'taunus': 0.00012123419073919972,
#  'bbc symphony orchestra': 0.0001704323137580404,
#  '1923': 0.0002337008224440811,
#  'evanescence': 0.000448518993114412,
#  'anton rubinstein': 0.0002340710742756766,
#  'recitative': 6.985742436986991e-05,
#  'the matrix': 0.00046803281104904477,
#  'cuban missile crisis': 0.0004907340391512685,
#  "lord's prayer": 0.0002674730066276389,
#  'ernest macmillan': 0.00042089628483303864,
#  'sri lanka': 9.475495300438937e-05,
#  'laozi': 0.0002749810532389657,
#  'phil spector': 0.0003580559071347332,
#  'catalonia': 0.00014622317689110163,
#  'prussia': 0.0004819339920298408,
#  'the adventures of tintin': 0.00021405149636372152,
#  'mindanao': 0.0001233665605236754,
#  'crustacean': 0.0003475038517962035,
#  'douglas adams': 0.00014119490981848087,
#  '1802': 0.0002250847512079394,
#  'francis bacon': 0.0002560481570132317,
#  'the lost world': 0.00015097013027260564,
#  'ben stiller': 0.00013870688653967698,
#  'ecosystem': 0.00015276712015662648,
#  'scots': 0.0002156711843218345,
#  'line of control': 0.00037635608592059947,
#  'itihasa': 0.0005918523531471889,
#  'light-emitting diode': 0.00011089630496457257,
#  'scandinavia': 0.0006870902143828158,
#  'concord, new hampshire': 0.00027362416696139147,
#  'rainbow flag': 0.0002977611112410494,
#  'governor general': 0.00011925939104221765,
#  'kazakhstan': 0.00014863407319692798,
#  'java': 0.00016680662109194795,
#  'prose': 8.339677157498627e-05,
#  'whale shark': 0.0002328571579918475,
#  'amateur': 0.00017326870949385927,
#  '1736': 0.00014557683699720385,
#  'anuket': 0.00015263333722262946,
#  'volcanism': 0.00022960020696989223,
#  'wikipedia:simple talk/archive 2': 0.000695586952756603,
#  'guantnamo province': 0.0001898699988743785,
#  'cardinal richelieu': 0.00033196545579247016,
#  'incubation period': 9.243099122187858e-05,
#  'sherlock holmes': 0.0003774354802347848,
#  'square foot gardening': 0.0001389158725001605,
#  'body piercing': 0.00010095262500446517,
#  'aphrodite': 0.00011760599469112623,
#  'ripuarian': 0.00014194639529428534,
#  'central asia': 0.0003518231326348033,
#  'performing music from memory': 0.0002991390918930272,
#  'bow (ship)': 0.00013468477268597238,
#  'leopold ii of belgium': 0.00017401014587476818,
#  'mexico': 0.00044877108133837217,
#  'placenta': 0.0001893808883299527,
#  'asmara': 0.00021587075209759916,
#  'december 22': 0.000490275931853932,
#  'kwame nkrumah': 0.0002739635708202597,
#  'comendador, elas pia': 0.00017451047935541727,
#  'six-day war': 0.0005208356503078278,
#  'wisconsin river': 0.00015803536868724274,
#  'hemera': 8.851857717341968e-05,
#  'el al': 0.00011707113477248904,
#  'glycolysis': 5.368913188744965e-05,
#  'john bunyan': 0.000412406067936401,
#  'system of a down': 0.0002945012129537127,
#  'theoretical computer science': 0.00028519722816112346,
#  'creativity': 0.00027747232073737477,
#  'argentine national anthem': 0.0001870060199745406,
#  'aegean sea': 0.0004897898766445984,
#  'kryptos': 0.00016225866125863748,
#  'bess truman': 0.00016768405301517472,
#  'superlative': 0.00017518121265709395,
#  'farming': 0.0003715963934772743,
#  'che guevara': 0.00010084135803652753,
#  'coat of arms of russia': 0.00037765942948935616,
#  "hilbert's paradox of the grand hotel": 0.00025926714598022973,
#  'january 1': 0.0005215177210490344,
#  '1252': 0.00032663993394269373,
#  'illusion': 0.0002214906916417006,
#  'halloween': 0.00022264382527029965,
#  'president of the united states': 0.0005799666439118636,
#  'armenian soviet socialist republic': 0.00015407981648384538,
#  'february 10': 0.0002919065534370835,
#  'he': 0.00019109817486277682,
#  'henry ii of england': 0.0004416423341898839,
#  'catholic church': 0.0007817794431465303,
#  'zachary taylor': 0.00023311460262559968,
#  'improvisation': 0.0002958388488630035,
#  'kayastha': 0.0003519878502639731,
#  'phil of the future': 0.00011240754292917614,
#  '1817': 0.0004349654807557184,
#  'malta': 0.0001256793184968451,
#  'border': 0.0001018756566515953,
#  'provost': 0.0001412922738234215,
#  'jose rizal': 0.00042621450300154114,
#  'crystal palace': 0.00011996240880478687,
#  'rectum': 9.805821883329449e-05,
#  'beaver': 0.00017543644240376228,
#  '2029': 0.00014664722898338436,
#  'the star-spangled banner': 0.000263046373719509,
#  '1681': 0.00015946292442913627,
#  'tourism': 0.000157345907142045,
#  'atomic force microscope': 3.1862999566570405e-05,
#  'wikipedia:disambiguation': 0.0005332419362138497,
#  'opium': 9.350807373279983e-05,
#  'downing street': 0.00010719956740087966,
#  'flatfish': 0.00017697453941574665,
#  'raphael': 0.0005102774249260874,
#  'movie': 0.0006561717403317512,
#  'sea anemone': 0.00020612304539359216,
#  'pythagorean theorem': 0.000393673512317563,
#  'thrust': 0.0001968019433373188,
#  '1461': 0.00017082720315306132,
#  'escopetarra': 0.00011984568798369843,
#  'adolescence': 0.00020012242821588526,
#  'marxist economics': 0.00047913055937092493,
#  'prime minister of the united kingdom': 0.000491326391448485,
#  'roald amundsen': 8.532617618609141e-05,
#  'checksum': 0.00021641890391252392,
#  'james ii of england': 0.00022210501922546893,
#  'anime': 0.0001882568027861779,
#  'mutation': 0.0001310846517245347,
#  'apprenticeship': 0.00017486503228270978,
#  'jacob de gheyn iii (painting)': 6.314460548398046e-05,
#  'armenian genocide': 0.0005317250128793057,
#  'minuet': 0.00017597519441628795,
#  '27': 0.00025158318522867045,
#  'cetology': 8.512413314706897e-05,
#  '31 euphrosyne': 9.196365535372295e-05,
#  'internal energy': 0.0002356588020648116,
#  'august': 0.00015696849961702977,
#  'coat of arms': 0.00019111245238486845,
#  'heart': 0.0003736297129460106,
#  '1885': 0.0001620566646376064,
#  'karl carstens': 0.00029294829078022484,
#  'saint anna': 0.0001351065098268723,
#  'personal computer': 0.0003287031291724774,
#  'agastya': 9.303752992135007e-05,
#  'pomegranate': 0.00013555335685114302,
#  'existentialism': 0.0003939441056728826,
#  'distance': 9.737088188296699e-05,
#  'heligoland': 7.30651082931541e-05,
#  'domestication': 0.00020438814575085277,
#  'the prince': 0.0002881078768331223,
#  'pomerania': 0.00030006555386435837,
#  'slang': 0.00019521106870773038,
#  'phases of the moon': 0.00019691196389247145,
#  'thor': 0.00029359891546797823,
#  'jack lemmon': 0.00012998922997566905,
#  'brig, switzerland': 0.0001570548874937127,
#  'dardanelles': 0.00011431155512419651,
#  'rostov': 7.942547029151102e-05,
#  'nazko cone': 0.00015847161844547447,
#  'brandenburg gate': 0.0002163229157833262,
#  'cusco': 0.00020708293755323766,
#  'provinces of the netherlands': 0.0003788416062419438,
#  '1396': 0.00031971245177320374,
#  'wikipedia:simple talk/archive 16': 0.0005829339036470822,
#  'jutes': 0.0001101379286674053,
#  'polar moment of inertia': 0.00018322379225499605,
#  'bubonic plague': 2.1223463774821406e-05,
#  'macbeth': 0.0001962778419395898,
#  'eos': 7.504003958187402e-05,
#  'arianism': 0.00040386899094971095,
#  'list of english monarchs': 0.0002585758069439959,
#  'united states house of representatives': 0.0002546002346457136,
#  'edward i of england': 0.0005617057311925457,
#  'guru granth sahib': 0.00011035975915096416,
#  'iapetos': 7.904727719680333e-05,
#  'elephants dream': 0.00037092552065257854,
#  'embryology': 0.0002255063287378186,
#  'category:7th century': 0.0001930062081573056,
#  'town privileges': 0.00019626009397388016,
#  'peripheral nervous system': 0.00010197427084832476,
#  'law of large numbers': 0.0004463165458829593,
#  'eritrea': 7.837716748387548e-05,
#  '303': 0.00018948320569347107,
#  'dodo': 0.00015034060720605234,
#  'poole': 0.00020186421397925774,
#  'j. k. rowling': 0.00024414347184606325,
#  'north': 0.00021664485531251753,
#  'anti-tank dog': 8.214853461783451e-05,
#  "wikipedia:administrators' noticeboard/current issues and requests archive 4": 0.00024358819146385366,
#  'ara gevorgyan': 0.0002095529788995068,
#  'jns jakob berzelius': 0.0001241386306618872,
#  'mouthpiece (brass)': 0.0001599489137160915,
#  'tatami': 0.00017361672646014727,
#  'sacred heart': 0.0006770007369975125,
#  'gary coleman': 0.0001160083688040418,
#  '886': 7.965968987785885e-05,
#  'anchorage, alaska': 8.869904699335369e-05,
#  'greater london': 0.00011497783347961762,
#  'wood grain': 8.291697646777043e-05,
#  'perfume': 0.00036456992251244233,
#  'prison': 0.00029557082614852957,
#  'corinthians': 0.00017869008465910258,
#  'april 19': 0.00043077472177144223,
#  'bagel': 0.00011083460809910565,
#  'diogenes of sinope': 0.0001462642400782091,
#  'crusinallo': 0.00022765541103678816,
#  'glosa': 9.900269934133651e-05,
#  '1718': 0.00021430759865161199,
#  'jejunum': 0.000149638450039116,
#  'decatur, illinois': 0.00014603983428050301,
#  'noble energy': 9.398238404374248e-05,
#  'template:navbox generic/doc': 0.00021614827087604554,
#  'category:1510s': 0.00014203223524331623,
#  'neck (disambiguation)': 0.00010114830884230733,
#  'category:1910s': 0.0001856354727013544,
#  'oak': 0.00018718166907535382,
#  'vought f-8 crusader': 0.00015128506226621226,
#  'sydney harbour bridge': 0.0001041311281100447,
#  'zeppelin': 0.00014915561526206131,
#  'bergstrae route': 0.00011693943450058971,
#  'physical coefficient': 0.00010920192915574398,
#  'bryozoa': 0.00028912610762890114,
#  'cactus': 0.00013843638874301638,
#  'steven spielberg': 0.00014527652224556332,
#  'intelligent design': 0.00034021865997366745,
#  'category:1440s': 0.00013349940688721292,
#  'confucianism': 0.00010679251156765021,
#  'single (music)': 0.00027304569538094025,
#  'sugarcane': 0.00015672895379932237,
#  'moses': 0.0004713555029886003,
#  'secretary of state': 0.00042243923853326284,
#  'manaus': 0.0004298799146732595,
#  'star trek': 0.00031226721983846993,
#  'pirates of the caribbean': 0.0004479387009968874,
#  'analysis': 0.00020821616166238555,
#  'mecca': 0.0001050004972791124,
#  'myanmar': 0.0002602916943098023,
#  'charles manson': 0.0002673390876955326,
#  'world wide web': 0.00017923058674186552,
#  'hygiene': 4.8040674829041315e-05,
#  'category:counties of the united states': 0.00023069312874450363,
#  'knot (speed)': 0.00022993864665004374,
#  'francis poulenc': 0.0002510428672088233,
#  'statue': 0.00010968653509220188,
#  'partition of india': 0.0003420043112288177,
#  'chobits': 0.00018407180528645347,
#  'charles gounod': 0.0002802697475898529,
#  'saint (disambiguation)': 0.000277452493424316,
#  '1280': 0.00032601587487170246,
#  'internet slang': 0.00024575201456927777,
#  'ketchup': 0.00011151524577085449,
#  'medal of honor': 7.574298496126458e-05,
#  '1984': 0.00046854503461486133,
#  'league (unit)': 0.0002739429681010781,
#  'pol pot': 0.00026081408168008896,
#  'albiorix (moon)': 0.00011186647964988718,
#  'minister-president': 0.0004067072034217986,
#  'mongol empire': 0.0001792794544573673,
#  'rebec': 0.0001005726167341878,
#  'jyllands-posten muhammad cartoons controversy': 8.740178289359732e-05,
#  'alfred hitchcock': 0.00016602087823459276,
#  'hestia': 7.85846843195428e-05,
#  'ruhleben p.o.w. camp': 0.00033029521693329455,
#  'mountain': 0.00045077200966955764,
#  'stevenage': 0.0001109098352293625,
#  'old english': 0.00010389937917980966,
#  'relief': 0.00016236443931661322,
#  'battle of the philippine sea': 0.00018810137164261453,
#  'iglesia ni cristo': 0.0003469876264014985,
#  'warrnambool, victoria': 0.00014213338411172728,
#  'fountain of youth': 9.237171883799869e-05,
#  'category:1030s': 0.00014680068977729357,
#  'wikipedia:shortcut': 0.00016577549434298018,
#  'wall of voodoo': 0.00028209047420402547,
#  'mary rose': 0.00022772199091124806,
#  'komrno': 0.00041812690536121845,
#  'wood': 0.00015229600335172857,
#  'johann sebastian bach': 0.00038408559383648226,
#  'peach': 6.552733184681558e-05,
#  'treaty of versailles': 0.0007170830916594373,
#  'petr eben': 0.0003286417389181002,
#  'trojan horse': 3.3405070803220156e-05,
#  'june 7': 0.00041408272884871,
#  'continental army': 0.0003196856374222591,
#  'harold harefoot': 0.00011323867862602362,
#  'hailstone': 0.00013373004633500087,
#  '1': 0.00033146905907161325,
#  'eastern europe': 0.00031088181382111623,
#  'stone age': 0.00014692288987954393,
#  'santo domingo': 0.00042861584893830055,
#  'himalayas': 0.0007003035101405674,
#  'united states bill of rights': 0.0006532242463918114,
#  'hu': 0.00021438562774191697,
#  'the new yorker': 0.00014650584570155548,
#  'satellite (artificial)': 0.0002197046624711201,
#  'wikipedia:simple talk/archive 6': 0.000520628238535768,
#  'wikipedia:simple talk/archive 13': 0.00042840695624573715,
#  'artificial sweetener': 0.0001235924920774147,
#  '1988': 0.0003298772068408283,
#  'robert college': 0.00025746294889827215,
#  'defibrillation': 0.00014771410547932725,
#  'whaling': 0.00015342591226663073,
#  'bulgaria': 0.00032302753101202334,
#  'category:1810s': 0.00015793760586133368,
#  'neoliberalism': 0.00016735888055140785,
#  'stomach': 0.0002671430557340714,
#  'overland expedition': 0.0005347624174462924,
#  'vlad iii the impaler': 0.00031472532366568493,
#  'wind speed': 0.00010099415147819877,
#  'croatia': 0.00028527906245634055,
#  'ice': 0.00018629281082760697,
#  'intelligence quotient': 0.0005264000529095584,
#  'prehistoric britain': 0.0006472375997830542,
#  'hanuman': 0.00010216965026428247,
#  'self-strengthening movement': 0.00015015815202825108,
#  'angers': 0.00019531207968385853,
#  'robert schumann': 0.00035725118647388256,
#  'surface': 0.00032255176830027,
#  'cell growth': 0.00010634074885090619,
#  'rhine river': 0.00019691352207465237,
#  'list of u.s. state mottos': 0.00018688000803690876,
#  'ontario': 0.00035551959320748275,
#  'parque del buen retiro': 0.00019144007097157047,
#  'sex': 0.00032070411279666084,
#  'april 6': 0.0004203768832892295,
#  'jean sibelius': 0.00042357071935665905,
#  'terrorism': 0.00013812511322729476,
#  'ewok': 0.00011471872733926616,
#  'smallpox': 0.00014066683413153976,
#  'dolphin': 0.000134908326988617,
#  'question mark': 0.00023530642196175993,
#  'category:19th century': 0.00021582006968769743,
#  'costa rica': 0.00025464920769669195,
#  'battle of badr': 0.00012654905017976448,
#  'spencer tracy': 0.00021008107778915254,
#  'national democratic party of germany': 0.00015625570452085322,
#  'body': 0.00031334106730455637,
#  'talk show': 0.00017092558321470257,
#  'lecture': 0.00017953314943132507,
#  'volume': 0.0006409876938787618,
#  'solid': 0.0004519323673905243,
#  'hasidic judaism': 0.00021815772091235476,
#  'new economic policy': 0.00019787033890972713,
#  'albert coady wedemeyer': 0.0002174989060163984,
#  'category:1310s': 0.00012434426482764896,
#  'albany, new york': 0.00028667507388384546,
#  'gas compressor': 0.00023869849086239129,
#  'shot put': 0.0003383820384640959,
#  '168 bc': 7.000149202984984e-05,
#  'category:1610s': 0.0001568679086149488,
#  'ume': 0.00012991603533008808,
#  'georgian uprising of texel': 0.0004665258272011413,
#  'cache (computing)': 0.0004050286102711997,
#  'daphne (mythology)': 9.709402981238672e-05,
#  'middle east': 0.0001749979441642673,
#  'jack-in-the-box': 0.00016471190868678616,
#  'spider': 0.0003347812096263846,
#  'arachnid': 0.00021918850286818808,
#  'mount st. helens': 0.0003091077713367279,
#  'toy story': 0.00037954605405403314,
#  'faq': 0.0001459905331403365,
#  '1102': 0.00026008783485445666,
#  'metal': 0.00037634717606833024,
#  'archipelago': 0.00011976843525356619,
#  'n': 0.00023695224271088182,
#  'deforestation': 0.00016994492546704452,
#  'shade': 0.00010282069017832193,
#  'zoroaster': 8.277253549537836e-05,
#  'cryolophosaurus': 0.00011231213965020757,
#  'category:6th century': 0.00019078950262247014,
#  'buto': 8.458651420704116e-05,
#  'hypothalamus': 0.00018356064428504156,
#  'national football league': 0.000537740176008706,
#  'hurricane lorenzo (2007)': 0.00013275446755936076,
#  'textile': 0.00019695766560087475,
#  'february 15': 0.00019360345154343896,
#  'cleanliness': 7.547440168903021e-05,
#  'johannesburg': 0.00017013523752133276,
#  'common chimpanzee': 0.00031055194661050374,
#  ...}

# %% [markdown]
# # Using Normal Dataset for PageRank

# %%
pr = nx.pagerank(PRGC)

# %%
pr
# Out:
# {'iliad': 5.281689695589627e-05,
#  'ilham aliyev': 5.281689695589627e-05,
#  'category:1943 births': 5.281689695589627e-05,
#  'category:history of russia': 5.281689695589627e-05,
#  'kathleen blanco': 5.281689695589627e-05,
#  'category:1798 births': 5.281689695589627e-05,
#  'aetyonyx': 5.281689695589627e-05,
#  'category:1894 deaths': 5.281689695589627e-05,
#  'template:rfa': 5.281689695589627e-05,
#  'becker (tv series)': 5.281689695589627e-05,
#  'wrestlemania (ppv series)': 5.281689695589627e-05,
#  'template:user movies': 5.281689695589627e-05,
#  'the adventures of huckleberry finn': 5.281689695589627e-05,
#  'weapons': 0.0001528235584903303,
#  'ravi shanker': 5.281689695589627e-05,
#  'category:1152': 5.281689695589627e-05,
#  'the empire strikes back': 5.281689695589627e-05,
#  'telephone call': 5.347920663654016e-05,
#  'category:french cyclists': 5.281689695589627e-05,
#  'lyle lovett': 5.281689695589627e-05,
#  'the church of scientology': 5.281689695589627e-05,
#  'stanford university': 5.281689695589627e-05,
#  'broward county, florida': 5.281689695589627e-05,
#  'category:1975 births': 5.281689695589627e-05,
#  'licensed to ill': 5.281689695589627e-05,
#  'learning disability': 5.281689695589627e-05,
#  'category:1564 deaths': 5.281689695589627e-05,
#  'societ sportiva calcio napoli': 5.281689695589627e-05,
#  'natural history': 8.207657295183473e-05,
#  'template:coord/input/dms': 5.281689695589627e-05,
#  'meryl streep': 5.281689695589627e-05,
#  'auto': 5.281689695589627e-05,
#  '1955': 0.0006938193319220558,
#  '1770s': 5.281689695589627e-05,
#  'peteh': 5.281689695589627e-05,
#  'bismarck (ship)': 5.281689695589627e-05,
#  'ohio river': 5.281689695589627e-05,
#  'list of german institutions': 5.281689695589627e-05,
#  'category:1436': 5.281689695589627e-05,
#  'class (biology)': 5.281689695589627e-05,
#  'runaway brain': 5.281689695589627e-05,
#  'category:1104': 5.281689695589627e-05,
#  'carer': 5.281689695589627e-05,
#  'tagalog language': 5.281689695589627e-05,
#  'category:user id-1': 5.281689695589627e-05,
#  'category:2003 movies': 5.281689695589627e-05,
#  'chief executive officer': 7.53354260977883e-05,
#  'grass': 0.0016701200081261406,
#  'sergei prokofiev': 5.281689695589627e-05,
#  'portsmouth f.c.': 5.281689695589627e-05,
#  'hajj': 5.281689695589627e-05,
#  'wikipedia:reverting': 5.281689695589627e-05,
#  're': 7.53354260977883e-05,
#  'kyoto station': 5.281689695589627e-05,
#  'pcp': 5.281689695589627e-05,
#  'balfour declaration of 1917': 5.281689695589627e-05,
#  '1489': 7.938945979554747e-05,
#  'fagatogo, american samoa': 5.281689695589627e-05,
#  'factory': 0.0006129438287841692,
#  '1992 pacific hurricane season': 5.281689695589627e-05,
#  'insomnia': 5.782101454298339e-05,
#  '1258': 5.382822780682989e-05,
#  'category:1787': 5.281689695589627e-05,
#  'category:mississippi': 5.281689695589627e-05,
#  'hillfort': 9.785395523968034e-05,
#  'willow': 5.281689695589627e-05,
#  'rfc 2822': 5.281689695589627e-05,
#  'chin': 5.403038045240479e-05,
#  'main': 6.407616152684229e-05,
#  '.com': 5.281689695589627e-05,
#  'natalie imbruglia': 5.281689695589627e-05,
#  '1916 summer olympics': 5.281689695589627e-05,
#  'oscilloscope': 0.00013177213215668758,
#  'developmental biology': 0.00010967301267987773,
#  'eagle': 0.00020824042262622929,
#  'nia': 5.281689695589627e-05,
#  "i'm with you": 5.281689695589627e-05,
#  'benzene': 0.0002211972003822795,
#  'grey squirrel': 5.281689695589627e-05,
#  'category:1878 births': 5.281689695589627e-05,
#  '1918': 0.0009468979887080603,
#  'category:886': 5.281689695589627e-05,
#  'amaterasu': 5.281689695589627e-05,
#  '50': 7.669778631735913e-05,
#  'arturo toscanini': 5.281689695589627e-05,
#  'capybara': 0.00011057152110827926,
#  'okinawan language': 5.281689695589627e-05,
#  'p-40 warhawk': 5.281689695589627e-05,
#  'megadeth': 5.281689695589627e-05,
#  'castle': 0.0004686591440106963,
#  'bf 109': 5.281689695589627e-05,
#  'dallas mavericks': 5.281689695589627e-05,
#  'category:gabon': 5.281689695589627e-05,
#  'aarhus': 5.281689695589627e-05,
#  'potassium permanganate': 5.281689695589627e-05,
#  'chicago (band)': 5.281689695589627e-05,
#  'banja luka region': 5.281689695589627e-05,
#  'category:1124': 5.281689695589627e-05,
#  'bhakti yoga': 5.281689695589627e-05,
#  'woodwind instrument': 6.182430861265309e-05,
#  'leopold mozart': 5.281689695589627e-05,
#  'template:country data hungary': 5.281689695589627e-05,
#  'b-29': 5.281689695589627e-05,
#  'tashiro masashi': 5.281689695589627e-05,
#  'category:1715 deaths': 5.281689695589627e-05,
#  'wikipedia:audio help': 5.281689695589627e-05,
#  'foot': 0.00038527236117571535,
#  'm/s': 5.281689695589627e-05,
#  'religious': 0.0006872674352566617,
#  'template:probability distribution/link density': 5.281689695589627e-05,
#  'universe': 0.0015972986992126839,
#  'prime minister of greenland': 5.281689695589627e-05,
#  'monotremes': 5.281689695589627e-05,
#  'plants': 0.0009618160704187894,
#  'exhibitionism': 5.281689695589627e-05,
#  'nuclear missiles': 5.281689695589627e-05,
#  'samudra manthan': 5.281689695589627e-05,
#  'yankee stadium (1923)': 5.281689695589627e-05,
#  'foci': 5.281689695589627e-05,
#  'help:user preferences help': 5.281689695589627e-05,
#  'potsdam': 5.281689695589627e-05,
#  'micropachycephalosaurus': 5.281689695589627e-05,
#  'california institute of technology': 5.281689695589627e-05,
#  'baby boy': 5.281689695589627e-05,
#  'kde': 5.281689695589627e-05,
#  'arika yumemiya': 5.281689695589627e-05,
#  'system international': 5.281689695589627e-05,
#  'category:user hy-n': 5.281689695589627e-05,
#  'kawaramachi station': 5.281689695589627e-05,
#  'template:country data united states': 5.281689695589627e-05,
#  'order of magnitude': 5.281689695589627e-05,
#  'burundi': 5.281689695589627e-05,
#  'diaoyutai islands': 5.281689695589627e-05,
#  'light speed': 0.00046816040114141605,
#  'ebola virus': 5.281689695589627e-05,
#  'spectrometer': 0.00023048333536607147,
#  '1750': 7.541088252935653e-05,
#  'rene rivkin': 5.281689695589627e-05,
#  'category:30s births': 5.281689695589627e-05,
#  'frankfurt': 5.281689695589627e-05,
#  'list of bridges': 5.281689695589627e-05,
#  'copland': 5.281689695589627e-05,
#  'southbridge, massachusetts': 5.281689695589627e-05,
#  'neurotoxin': 0.00010231614877732503,
#  '21 april': 5.281689695589627e-05,
#  'biosphere': 6.908027911392941e-05,
#  'apostle': 5.281689695589627e-05,
#  'category:1601 deaths': 5.281689695589627e-05,
#  'oligarchy': 5.281689695589627e-05,
#  'category:1610s deaths': 5.281689695589627e-05,
#  'emperor go-sanj': 5.281689695589627e-05,
#  'category:2006 songs': 5.281689695589627e-05,
#  'category:2004': 5.281689695589627e-05,
#  'autobahn': 5.925076242500829e-05,
#  'category:falconiformes': 5.281689695589627e-05,
#  'maritime museum, fluvial and harbor of rouen': 5.281689695589627e-05,
#  'theme and variations': 5.281689695589627e-05,
#  'pluto (dwarf planet)': 5.281689695589627e-05,
#  'stopclock': 5.281689695589627e-05,
#  'category:1756 births': 5.281689695589627e-05,
#  'category:1987 movies': 5.281689695589627e-05,
#  'jazz fusion': 0.00017272833773019735,
#  'piceno': 5.281689695589627e-05,
#  'castration': 9.785395523968034e-05,
#  'walter sisulu': 5.281689695589627e-05,
#  'category:organizations': 5.281689695589627e-05,
#  'vegetarianism': 5.281689695589627e-05,
#  'k': 5.281689695589627e-05,
#  'harmony': 0.00019360362868206833,
#  'anglesey': 5.281689695589627e-05,
#  'united states air force strategic bombers': 5.281689695589627e-05,
#  'gerald r. ford': 5.281689695589627e-05,
#  'simple english gfdl': 5.281689695589627e-05,
#  'urine': 0.0004171618673452077,
#  'basingstoke': 5.281689695589627e-05,
#  'lichfield': 5.281689695589627e-05,
#  'category:engineering': 5.281689695589627e-05,
#  'saprophyte': 5.281689695589627e-05,
#  'michiel de ruyter': 5.281689695589627e-05,
#  'elas pia province': 5.281689695589627e-05,
#  'chorlton-on-medlock': 5.281689695589627e-05,
#  'john f kennedy': 5.281689695589627e-05,
#  'metaphysics': 8.434283775454512e-05,
#  'template:neutrality': 5.281689695589627e-05,
#  'advanced': 5.281689695589627e-05,
#  'granite': 0.000144654040837189,
#  'chilopoda': 5.281689695589627e-05,
#  'decimal separator': 9.785395523968034e-05,
#  '1931': 0.00043102439272986443,
#  'atomic force microscope': 5.281689695589627e-05,
#  'coliseum': 5.281689695589627e-05,
#  'terrestrial ecoregion': 0.0002580159917195306,
#  'category:1385': 5.281689695589627e-05,
#  'category:ruins': 5.281689695589627e-05,
#  'daniel schneidermann': 5.281689695589627e-05,
#  'chastity belt': 5.281689695589627e-05,
#  '1078': 0.00014225135305342892,
#  'wikipedia:interlanguage links': 5.281689695589627e-05,
#  'category:1676': 5.281689695589627e-05,
#  'washing': 6.782924971715763e-05,
#  'category:african politicians': 5.281689695589627e-05,
#  'masaccio': 5.281689695589627e-05,
#  'category:1930 movies': 5.281689695589627e-05,
#  '1262': 9.803126649276611e-05,
#  'template:pak': 5.281689695589627e-05,
#  'anisoptera': 5.281689695589627e-05,
#  'category:user templates': 5.281689695589627e-05,
#  'gottlieben': 5.281689695589627e-05,
#  'mariana islands': 5.281689695589627e-05,
#  'hamlet (place)': 5.281689695589627e-05,
#  'u.s. virgin islands': 5.281689695589627e-05,
#  'category:1319 deaths': 5.281689695589627e-05,
#  'richard gere': 5.281689695589627e-05,
#  'european charter for minority or regional languages': 5.281689695589627e-05,
#  'mulatto': 5.8446529241369285e-05,
#  'category:1093 deaths': 5.281689695589627e-05,
#  'weymouth': 5.281689695589627e-05,
#  'sedan (disambiguation)': 5.281689695589627e-05,
#  'category:1460': 5.281689695589627e-05,
#  'category:1424': 5.281689695589627e-05,
#  'moksha': 5.281689695589627e-05,
#  'bow (music)': 5.281689695589627e-05,
#  'real-time strategy': 5.281689695589627e-05,
#  'template:underconstruction': 5.281689695589627e-05,
#  'barnes & noble': 5.281689695589627e-05,
#  'jubal early': 5.281689695589627e-05,
#  'category:1401': 5.281689695589627e-05,
#  'prince (musician)': 5.281689695589627e-05,
#  'homophony': 5.281689695589627e-05,
#  'category:1922 establishments': 5.281689695589627e-05,
#  'category:1690s deaths': 5.281689695589627e-05,
#  'double axel': 5.281689695589627e-05,
#  'york, england': 5.281689695589627e-05,
#  'category:books by michael crichton': 5.281689695589627e-05,
#  'digital signal': 0.000846016400030667,
#  'autistic': 5.281689695589627e-05,
#  'ennetbaden': 5.281689695589627e-05,
#  'delphi': 5.281689695589627e-05,
#  'captain america': 5.281689695589627e-05,
#  'category:user pt-n': 5.281689695589627e-05,
#  'bartolomeu dias': 5.281689695589627e-05,
#  '1131': 0.00017223879076902542,
#  'susan sarandon': 5.281689695589627e-05,
#  'parallel projection': 5.281689695589627e-05,
#  'royal palace of madrid': 5.281689695589627e-05,
#  'category:towns in north america': 5.281689695589627e-05,
#  'granny panties': 5.281689695589627e-05,
#  'percussion instrument': 5.281689695589627e-05,
#  'germanic languages': 5.281689695589627e-05,
#  'chi-chi': 5.281689695589627e-05,
#  'virgil': 5.281689695589627e-05,
#  'boer': 5.281689695589627e-05,
#  'mace (spice)': 5.281689695589627e-05,
#  'lage': 5.281689695589627e-05,
#  'nndb': 5.281689695589627e-05,
#  'category:conifers': 5.281689695589627e-05,
#  'template:sockpuppet category': 5.281689695589627e-05,
#  'star': 0.0014914363332296438,
#  'template:divstylegreen': 5.281689695589627e-05,
#  'template:country flag2': 5.281689695589627e-05,
#  'template:loop': 5.281689695589627e-05,
#  'schumann': 5.281689695589627e-05,
#  'olympic flight museum': 5.281689695589627e-05,
#  "bishop's stortford": 5.281689695589627e-05,
#  'template:location map': 5.281689695589627e-05,
#  'alan carr': 5.281689695589627e-05,
#  'glue': 0.000781046308356847,
#  'scales (music)': 5.281689695589627e-05,
#  'subtropical cyclone': 0.00014072966862256384,
#  'murasaki shikibu': 5.281689695589627e-05,
#  'product (business)': 5.281689695589627e-05,
#  'associated board of the royal schools of music': 5.281689695589627e-05,
#  'yuryuzan (town)': 5.281689695589627e-05,
#  'r.a.f.': 5.281689695589627e-05,
#  'official': 0.00012264071696532427,
#  'category:proposed very good articles': 5.281689695589627e-05,
#  'safety curtain': 5.281689695589627e-05,
#  'maori language': 5.281689695589627e-05,
#  'category:1179 deaths': 5.281689695589627e-05,
#  '1896': 0.001129544635026129,
#  'soviet socialist republic': 5.281689695589627e-05,
#  'crusade': 0.0002152709720769088,
#  'dusseldorf': 5.281689695589627e-05,
#  'right-wing politics': 5.281689695589627e-05,
#  'dubhghlas de hde': 5.281689695589627e-05,
#  'cherry pie': 5.281689695589627e-05,
#  'category:domesticated animals': 5.281689695589627e-05,
#  'whigs': 5.281689695589627e-05,
#  'unix': 5.281689695589627e-05,
#  'triple h': 5.281689695589627e-05,
#  'hymm': 5.281689695589627e-05,
#  'astronomer royal': 5.281689695589627e-05,
#  'californication': 5.281689695589627e-05,
#  'category:1597': 5.281689695589627e-05,
#  'metamorphosis': 0.0004444231676348653,
#  'category:belgian royalty': 5.281689695589627e-05,
#  'gps': 5.281689695589627e-05,
#  'know': 5.281689695589627e-05,
#  'inns of court': 5.281689695589627e-05,
#  'olympic stadium (athens)': 5.281689695589627e-05,
#  'tettigoniidae': 5.281689695589627e-05,
#  'category:1518': 5.281689695589627e-05,
#  'cross-country race': 5.281689695589627e-05,
#  'customs': 0.0001231491928359864,
#  'category:1442 births': 5.281689695589627e-05,
#  'oread': 5.281689695589627e-05,
#  'sneeze': 5.311125681396023e-05,
#  'december 31': 5.281689695589627e-05,
#  '1612': 8.021897320383693e-05,
#  'taipei county': 5.281689695589627e-05,
#  'ean': 5.281689695589627e-05,
#  'template:nyse2': 5.281689695589627e-05,
#  '222': 5.446125221557776e-05,
#  'homestar runner': 5.281689695589627e-05,
#  'lab': 5.281689695589627e-05,
#  'allowance': 5.281689695589627e-05,
#  'patriotic': 7.53354260977883e-05,
#  'puccini': 5.281689695589627e-05,
#  'springfield, illinois': 5.281689695589627e-05,
#  'magpie': 0.00013287215660554255,
#  'filipendula': 5.281689695589627e-05,
#  'european charter for regional and minority languages': 5.281689695589627e-05,
#  'continental circuits': 5.281689695589627e-05,
#  'category:1087': 5.281689695589627e-05,
#  'miles "tails" prower': 5.281689695589627e-05,
#  'eye (cyclone)': 0.0003176107550174935,
#  'category:1991 albums': 5.281689695589627e-05,
#  'fu xiancai': 5.281689695589627e-05,
#  'gazelle': 0.00036224659316409796,
#  'stuart dynasty': 5.281689695589627e-05,
#  'nearctic': 5.281689695589627e-05,
#  'blender': 6.714009134572899e-05,
#  'lorca': 5.281689695589627e-05,
#  'eukaryote': 0.001028931976162547,
#  'celine dion': 5.281689695589627e-05,
#  'category:270s': 5.281689695589627e-05,
#  'thoroughbred': 5.281689695589627e-05,
#  'john barrowman': 5.281689695589627e-05,
#  'lauscha': 5.281689695589627e-05,
#  'program music': 5.281689695589627e-05,
#  'regions of peru': 5.281689695589627e-05,
#  'mollusk': 6.407616152684229e-05,
#  'stonemasonry': 5.281689695589627e-05,
#  'stephano (moon)': 5.281689695589627e-05,
#  'diabetes insipidus': 6.0323073336526954e-05,
#  'hentai': 0.00017187447171193603,
#  'parliament of england': 5.281689695589627e-05,
#  'opera (browser)': 5.281689695589627e-05,
#  'paragraph': 0.0005045414826147192,
#  'renewable energy': 9.785395523968034e-05,
#  'herens (district)': 5.281689695589627e-05,
#  'goat beach': 5.281689695589627e-05,
#  'wikipedia:blocks and bans': 5.281689695589627e-05,
#  'u2 (band)': 5.281689695589627e-05,
#  'paul simon': 5.281689695589627e-05,
#  'urbain le verrier': 5.281689695589627e-05,
#  'gulfport-biloxi, mississippi metropolitan statistical area': 5.281689695589627e-05,
#  'pot pie': 5.281689695589627e-05,
#  'joseph priestly': 5.281689695589627e-05,
#  'boredom': 5.281689695589627e-05,
#  'houston dynamo': 5.281689695589627e-05,
#  'martial arts': 0.00019468363054981608,
#  'a320': 5.281689695589627e-05,
#  '1. fc kln': 5.281689695589627e-05,
#  'calabria': 5.281689695589627e-05,
#  'flask': 9.785395523968034e-05,
#  'template:armenian history': 5.281689695589627e-05,
#  'degrees': 5.281689695589627e-05,
#  'template:infobox film': 5.281689695589627e-05,
#  'category:forms of government': 5.281689695589627e-05,
#  'esztergom': 5.281689695589627e-05,
#  'category:persian poets': 5.281689695589627e-05,
#  'category:1890 births': 5.281689695589627e-05,
#  'robert browning': 5.281689695589627e-05,
#  'malcolm mcdowell': 5.281689695589627e-05,
#  'category:occupations': 5.281689695589627e-05,
#  'september 29': 5.281689695589627e-05,
#  'chloroplast': 0.0004517144749574902,
#  'template:football kit': 5.281689695589627e-05,
#  'monrovia': 5.281689695589627e-05,
#  'united states military': 5.281689695589627e-05,
#  'mythology': 0.0002646566565062313,
#  'spongebob squarepants': 5.281689695589627e-05,
#  'category:1970s in music': 5.281689695589627e-05,
#  'category:1664': 5.281689695589627e-05,
#  'malacostracan crustacean': 5.281689695589627e-05,
#  'psychedelic rock': 0.00021974422110151678,
#  'salom': 5.281689695589627e-05,
#  '1765': 0.00015487387057842733,
#  'jordan river': 5.281689695589627e-05,
#  'united states of america': 5.281689695589627e-05,
#  'silica': 0.00044658623263329843,
#  'incisor': 0.00028735732022460515,
#  'category:french scientists': 5.281689695589627e-05,
#  'octopi': 5.281689695589627e-05,
#  'manure': 5.281689695589627e-05,
#  'academy award for best picture (1930s)': 5.281689695589627e-05,
#  'cromwell current': 5.281689695589627e-05,
#  'gandalf': 5.281689695589627e-05,
#  'yeovil, somerset': 5.281689695589627e-05,
#  'template:pvgood/doc': 5.281689695589627e-05,
#  'synth': 5.281689695589627e-05,
#  'category:user ar-4': 5.281689695589627e-05,
#  'george washington bridge': 5.281689695589627e-05,
#  'morals': 5.281689695589627e-05,
#  'list of mathematics topics': 5.281689695589627e-05,
#  'category:spanish athletes': 5.281689695589627e-05,
#  'tainan county': 5.281689695589627e-05,
#  'movie theater': 0.0001428910135234644,
#  'june 30': 5.281689695589627e-05,
#  'taneda shouichi': 5.281689695589627e-05,
#  '1979': 0.0007510580567015109,
#  'snooker': 6.324920782586358e-05,
#  'allies': 5.281689695589627e-05,
#  'nursery (horticulture)': 5.281689695589627e-05,
#  'kura-araxes culture': 5.281689695589627e-05,
#  'most valuable player': 0.00018792807180724848,
#  'category:420s bc births': 5.281689695589627e-05,
#  'sconce': 5.281689695589627e-05,
#  'flag of soviet union': 5.281689695589627e-05,
#  'rhadamistus': 5.281689695589627e-05,
#  'slavn': 5.281689695589627e-05,
#  '1025': 0.0001358281565375443,
#  'amorphous solid': 5.281689695589627e-05,
#  'slade': 5.281689695589627e-05,
#  'category:aargau': 5.281689695589627e-05,
#  'category:commonwealth member states': 5.281689695589627e-05,
#  'cyberstalking': 5.281689695589627e-05,
#  'google videos': 5.281689695589627e-05,
#  'rugby league': 0.0001274699032573839,
#  'irbil province': 5.281689695589627e-05,
#  'faur': 5.281689695589627e-05,
#  'abu bakr': 5.281689695589627e-05,
#  'category:intelligence agencies': 5.281689695589627e-05,
#  'ring lardner': 5.281689695589627e-05,
#  'category:849 births': 5.281689695589627e-05,
#  'category:1718 births': 5.281689695589627e-05,
#  'dive bomber': 5.281689695589627e-05,
#  'category:germanic languages': 5.281689695589627e-05,
#  'metastasis': 0.00016841328060576482,
#  'deal or no deal': 5.281689695589627e-05,
#  'booing': 5.281689695589627e-05,
#  'category:afroasiatic languages': 5.281689695589627e-05,
#  'blossom': 6.687016128633782e-05,
#  'nigel barker': 5.281689695589627e-05,
#  'category:1994': 5.281689695589627e-05,
#  'v.f.l. bochum': 5.281689695589627e-05,
#  'monte carlo': 5.281689695589627e-05,
#  'category:900 deaths': 5.281689695589627e-05,
#  'category:1992 movies': 5.281689695589627e-05,
#  'mario party 6': 5.281689695589627e-05,
#  'democratic progressive party': 5.281689695589627e-05,
#  'category:channel islands': 5.281689695589627e-05,
#  'alexander von humboldt': 5.281689695589627e-05,
#  'the most honourable order of the bath': 5.281689695589627e-05,
#  'gregory peck': 5.281689695589627e-05,
#  'wohlenschwil': 5.281689695589627e-05,
#  'template:commons': 5.281689695589627e-05,
#  'category:debut albums': 5.281689695589627e-05,
#  'baritone': 0.0001292063481615133,
#  'alto flute': 6.336362007881536e-05,
#  'diseases': 6.970579381231529e-05,
#  'category:wikipedia metatemplates': 5.281689695589627e-05,
#  "skene's glands": 5.281689695589627e-05,
#  'category:semitic languages': 5.281689695589627e-05,
#  'february 06': 5.281689695589627e-05,
#  'meteor scatter communication': 5.281689695589627e-05,
#  'electromagnetic induction': 5.281689695589627e-05,
#  'robert ludlum': 5.281689695589627e-05,
#  'necktie': 8.58174707347206e-05,
#  'val klimer': 5.281689695589627e-05,
#  'category:irrational numbers': 5.281689695589627e-05,
#  'hungarian language': 5.281689695589627e-05,
#  'air force': 0.0001586539839227888,
#  'lord voldemort': 5.281689695589627e-05,
#  'genitals': 8.451348147156511e-05,
#  'snares penguin': 5.281689695589627e-05,
#  'international english language testing system': 5.281689695589627e-05,
#  'canton of obwalden': 5.281689695589627e-05,
#  '23 april': 5.281689695589627e-05,
#  "zaiger's genetics": 5.281689695589627e-05,
#  'yellow river': 5.281689695589627e-05,
#  'channel tunnel': 5.281689695589627e-05,
#  'moose': 5.281689695589627e-05,
#  'jess willard': 5.281689695589627e-05,
#  'new england revolution': 5.281689695589627e-05,
#  'direct democracy': 5.281689695589627e-05,
#  'astronomical opposition': 5.281689695589627e-05,
#  'category:people buried in westminster abbey': 5.281689695589627e-05,
#  '1350s': 9.785395523968034e-05,
#  'dependency': 5.281689695589627e-05,
#  'kisamor': 5.281689695589627e-05,
#  'category:996 deaths': 5.281689695589627e-05,
#  'pope': 0.0011482326413274147,
#  'template:country data korea': 5.281689695589627e-05,
#  'file system': 0.00010668697456664014,
#  'the seven wonders of the world': 5.281689695589627e-05,
#  'template:nndb name': 5.281689695589627e-05,
#  'category:230s deaths': 5.281689695589627e-05,
#  'robbie williams': 5.281689695589627e-05,
#  'category:1890s deaths': 5.281689695589627e-05,
#  'sandbox': 5.281689695589627e-05,
#  'legion of net. heroes': 5.281689695589627e-05,
#  '1529': 5.52173293475516e-05,
#  'category:succession templates': 5.281689695589627e-05,
#  'ecozone': 0.00021522597193082574,
#  'chemical warfare': 9.847996071834674e-05,
#  'survivor (song)': 5.281689695589627e-05,
#  'portuguese (disambiguation)': 5.281689695589627e-05,
#  'obsessive compulsive disorder': 5.281689695589627e-05,
#  'sivaya subramuniyaswami': 5.281689695589627e-05,
#  'crookes': 5.281689695589627e-05,
#  'category:serbian people': 5.281689695589627e-05,
#  'snuff': 5.8446529241369285e-05,
#  'sussex': 5.281689695589627e-05,
#  'spiny lobster': 5.281689695589627e-05,
#  'nfl': 5.281689695589627e-05,
#  'category:1190 deaths': 5.281689695589627e-05,
#  'template:country data arizona': 5.281689695589627e-05,
#  'mpaa film rating system': 5.281689695589627e-05,
#  'protagonist': 0.0009771732613489436,
#  'soprano': 0.000357448268954546,
#  'anaerobic organism': 7.53354260977883e-05,
#  'atoms': 0.0002928689910300249,
#  'regions of england': 5.281689695589627e-05,
#  'template:mda': 5.281689695589627e-05,
#  'spleen': 0.00023635678523192406,
#  'category:1550s births': 5.281689695589627e-05,
#  'kaleva': 5.281689695589627e-05,
#  'bratislava': 5.281689695589627e-05,
#  'caprinae': 5.281689695589627e-05,
#  'saint peter': 5.281689695589627e-05,
#  'norman rockwell': 5.281689695589627e-05,
#  'category:1617': 5.281689695589627e-05,
#  'decidable': 5.281689695589627e-05,
#  'otters': 5.281689695589627e-05,
#  'roma': 5.281689695589627e-05,
#  'sprain': 6.0323073336526954e-05,
#  'turtles': 5.281689695589627e-05,
#  'carl sagan': 5.281689695589627e-05,
#  'mariah carey': 5.281689695589627e-05,
#  'february 7': 5.281689695589627e-05,
#  'category:1918 deaths': 5.281689695589627e-05,
#  'ancient egypt': 5.281689695589627e-05,
#  'bbikon': 5.281689695589627e-05,
#  'rossini': 5.281689695589627e-05,
#  'belluno': 5.281689695589627e-05,
#  'offside rule': 5.281689695589627e-05,
#  'russian revolution': 5.281689695589627e-05,
#  'mummifying': 5.281689695589627e-05,
#  'herge': 5.281689695589627e-05,
#  'alan white': 5.281689695589627e-05,
#  'silly putty': 5.281689695589627e-05,
#  'alcoholism': 0.00027847401282017305,
#  'category:dwarf planets': 5.281689695589627e-05,
#  'elementary algebra': 5.281689695589627e-05,
#  'israel': 5.281689695589627e-05,
#  'co-operative party': 5.281689695589627e-05,
#  'template:user eo-3': 5.281689695589627e-05,
#  'river pegnitz': 5.281689695589627e-05,
#  'ming kipa': 5.281689695589627e-05,
#  'g-spot vibrator': 5.281689695589627e-05,
#  'espaa': 5.281689695589627e-05,
#  'category:5th century bc': 5.281689695589627e-05,
#  'erin sanders': 5.281689695589627e-05,
#  'ownership': 0.00012523873738733718,
#  'category:polish military aircraft': 5.281689695589627e-05,
#  'alchemy': 7.847116331516706e-05,
#  '30s': 7.669778631735913e-05,
#  'insulation': 5.281689695589627e-05,
#  'ananke group': 5.281689695589627e-05,
#  '4 january': 5.281689695589627e-05,
#  'milk': 0.0014070161526459509,
#  'federated states of micronesia': 5.281689695589627e-05,
#  'template:nor': 5.281689695589627e-05,
#  'heat engine': 0.00010845813141817973,
#  'lawsuit': 7.53354260977883e-05,
#  'kullervo': 5.281689695589627e-05,
#  'template:country data louisiana': 5.281689695589627e-05,
#  'solomon': 5.281689695589627e-05,
#  'category:1723 deaths': 5.281689695589627e-05,
#  'ashley massaro': 5.281689695589627e-05,
#  'category:1976 deaths': 5.281689695589627e-05,
#  'category:1640': 5.281689695589627e-05,
#  'bowing (music)': 5.281689695589627e-05,
#  'pope julius ii': 5.281689695589627e-05,
#  'namaste': 5.281689695589627e-05,
#  'category:1681 births': 5.281689695589627e-05,
#  'florida keys': 5.281689695589627e-05,
#  "the pilgrim's progress": 5.281689695589627e-05,
#  'us of a': 5.281689695589627e-05,
#  'erythropoietin': 5.426970528763124e-05,
#  'council of the european union': 5.281689695589627e-05,
#  'suga mama': 5.281689695589627e-05,
#  'contamination': 7.53354260977883e-05,
#  'ebro': 5.281689695589627e-05,
#  'horse chestnut': 5.281689695589627e-05,
#  'drum set': 5.281689695589627e-05,
#  'enceladus (moon)': 5.281689695589627e-05,
#  'orlando (disambiguation)': 5.281689695589627e-05,
#  'izumo province': 5.281689695589627e-05,
#  '1416': 5.526254595044615e-05,
#  'template:userboxtop': 5.281689695589627e-05,
#  'category:1280': 5.281689695589627e-05,
#  'captain of kpenick': 5.281689695589627e-05,
#  'landform': 0.0002177687101154294,
#  'audition': 7.908851428810365e-05,
#  'welsh': 5.281689695589627e-05,
#  'fijian language': 5.281689695589627e-05,
#  'global warming controversy': 5.281689695589627e-05,
#  'armenian catholic church': 5.281689695589627e-05,
#  'julius nyerere': 5.281689695589627e-05,
#  'black sabbath': 5.281689695589627e-05,
#  'bayernliga': 5.281689695589627e-05,
#  'crescent (disambiguation)': 5.281689695589627e-05,
#  'category:1024 deaths': 5.281689695589627e-05,
#  'lies': 0.00012488027673409913,
#  'template:mwi': 5.281689695589627e-05,
#  'fokker dr.i': 5.281689695589627e-05,
#  'sex toy': 6.826353622976614e-05,
#  'human digestive system': 5.281689695589627e-05,
#  'raymond roseliep': 5.281689695589627e-05,
#  'elder': 5.281689695589627e-05,
#  'template:commas': 5.281689695589627e-05,
#  'spectral line': 0.00014984698875394737,
#  'category:4th century bc': 5.281689695589627e-05,
#  'piri reis': 5.281689695589627e-05,
#  'bob marley': 5.281689695589627e-05,
#  'birr, switzerland': 5.281689695589627e-05,
#  'box of crayons': 5.281689695589627e-05,
#  'gamma rays': 5.366665277257145e-05,
#  'vyacheslav v. ivanov': 5.281689695589627e-05,
#  'volleyball': 9.80831240795446e-05,
#  'electricity generation': 5.281689695589627e-05,
#  'hokkaido wolf': 5.281689695589627e-05,
#  'iron man (disambiguation)': 5.281689695589627e-05,
#  'hockey stick': 6.782924971715763e-05,
#  'imperialism': 0.0001428910135234644,
#  '130s': 5.281689695589627e-05,
#  'cornbread': 0.00011056522309315404,
#  'coonskin cap': 5.281689695589627e-05,
#  'thunor': 5.281689695589627e-05,
#  'photography': 0.0005180071506991564,
#  'popcorn': 0.00018275870775576877,
#  'category:1248 births': 5.281689695589627e-05,
#  'pyinmana': 5.281689695589627e-05,
#  'persian lime': 5.281689695589627e-05,
#  'petronas towers': 5.281689695589627e-05,
#  'syphilis': 0.00012045854516813506,
#  'book of job': 5.281689695589627e-05,
#  'category:1860s': 5.281689695589627e-05,
#  'blade runner': 5.281689695589627e-05,
#  'margaret whitman': 5.281689695589627e-05,
#  'yankee doodle dandy': 5.281689695589627e-05,
#  'orange (fruit)': 5.281689695589627e-05,
#  'ayatollah rafsanjani': 5.281689695589627e-05,
#  'baptising': 5.281689695589627e-05,
#  'eagles (band)': 5.281689695589627e-05,
#  'general relativity': 0.0004912037042771942,
#  'pennines': 5.281689695589627e-05,
#  'candlemass': 5.281689695589627e-05,
#  'infrastructure': 0.00020066108130757963,
#  'category:1990 disestablishments': 5.281689695589627e-05,
#  'coxpox': 5.281689695589627e-05,
#  'mike tyson': 5.281689695589627e-05,
#  'bismark (ship)': 5.281689695589627e-05,
#  'asti': 5.281689695589627e-05,
#  'hindbrain': 0.00023977248801215225,
#  'category:people': 5.281689695589627e-05,
#  'fumie suguri': 5.281689695589627e-05,
#  'melilla': 5.281689695589627e-05,
#  'staff (stick)': 5.281689695589627e-05,
#  'spruce (disambiguation)': 5.281689695589627e-05,
#  'cypriot': 5.281689695589627e-05,
#  'veltheim, aargau': 5.281689695589627e-05,
#  'holyrood abbey': 5.281689695589627e-05,
#  'nitrogen fixation': 5.281689695589627e-05,
#  'levant (disambiguation)': 5.281689695589627e-05,
#  'template:che': 5.281689695589627e-05,
#  'sokol viktoria ikov': 5.281689695589627e-05,
#  'diet (assembly)': 5.281689695589627e-05,
#  'shepton mallet': 5.281689695589627e-05,
#  'johann albrechtsberger': 5.281689695589627e-05,
#  'tuple': 5.281689695589627e-05,
#  'template:nihongo': 5.281689695589627e-05,
#  'shropshire': 5.281689695589627e-05,
#  'category:continents': 5.281689695589627e-05,
#  'template:coord/dec2dms/d1': 5.281689695589627e-05,
#  'endangered species': 0.00013780389262962734,
#  'santa cruz river': 5.281689695589627e-05,
#  'fifth avenue': 5.281689695589627e-05,
#  '1105': 0.0002994678020379902,
#  'jurassic park: operation genesis': 5.281689695589627e-05,
#  '1809': 0.00042736463586199187,
#  'lazio': 5.281689695589627e-05,
#  '1 e8 m': 5.281689695589627e-05,
#  'akihito': 5.281689695589627e-05,
#  'template:country data south carolina': 5.281689695589627e-05,
#  'category:ides': 5.281689695589627e-05,
#  'hillary clinton': 5.281689695589627e-05,
#  'san jacinto fault': 5.281689695589627e-05,
#  'category:1703 deaths': 5.281689695589627e-05,
#  'category:1133': 5.281689695589627e-05,
#  'khmer rouge': 5.281689695589627e-05,
#  'photographer': 0.0003937890305409533,
#  'template:country data pol': 5.281689695589627e-05,
#  'emergency medicine': 5.281689695589627e-05,
#  "ma'at": 5.281689695589627e-05,
#  'trustworthiness': 5.281689695589627e-05,
#  'the flowers of romance': 5.281689695589627e-05,
#  'category:15th century births': 5.281689695589627e-05,
#  'service (economics)': 5.281689695589627e-05,
#  'encyclopedia of computer terms': 5.281689695589627e-05,
#  'category:935': 5.281689695589627e-05,
#  'johann georg albrechtsberger': 5.281689695589627e-05,
#  'disappearance of madeleine mccann': 5.281689695589627e-05,
#  'morumbi stadium': 5.281689695589627e-05,
#  'richard strauss': 5.281689695589627e-05,
#  'reggie fils aime': 5.281689695589627e-05,
#  'category:wikipedians by location': 5.281689695589627e-05,
#  'category:olympic gold medalists': 5.281689695589627e-05,
#  'category:1457': 5.281689695589627e-05,
#  'khosrov iii the small': 5.281689695589627e-05,
#  'category:russian nobility': 5.281689695589627e-05,
#  'simple living': 6.407616152684229e-05,
#  'matterhorn': 5.281689695589627e-05,
#  'multiculturalism': 5.281689695589627e-05,
#  'northern mariana islands': 5.281689695589627e-05,
#  'yitzhak rabin': 5.281689695589627e-05,
#  'bochum': 5.281689695589627e-05,
#  '1068': 0.00011792783119330453,
#  'category:australian railways': 5.281689695589627e-05,
#  'orlando, florida': 5.281689695589627e-05,
#  'category:1475': 5.281689695589627e-05,
#  'die walkre': 5.281689695589627e-05,
#  'list of internet top-level domains': 5.281689695589627e-05,
#  'category:941': 5.281689695589627e-05,
#  'ruwer (region)': 5.281689695589627e-05,
#  'acorn': 5.767573277140881e-05,
#  'computer hardware': 0.0007771931931949248,
#  'category:user hr-4': 5.281689695589627e-05,
#  'canadian football': 5.281689695589627e-05,
#  'category:1271': 5.281689695589627e-05,
#  '1166': 6.57469314646403e-05,
#  'space marines': 5.281689695589627e-05,
#  'british indian ocean territory': 5.281689695589627e-05,
#  'magnet': 0.0009449755378999892,
#  'coordinated universal time': 5.281689695589627e-05,
#  'sean watkins': 5.281689695589627e-05,
#  'babylon': 5.281689695589627e-05,
#  'unicef': 5.281689695589627e-05,
#  'lamb': 6.170032355086245e-05,
#  '1100': 0.00014403564562179465,
#  'category:1948 books': 5.281689695589627e-05,
#  'shakespeare': 5.281689695589627e-05,
#  'similarity': 5.281689695589627e-05,
#  'template:infobox organization': 5.281689695589627e-05,
#  'ohana': 5.281689695589627e-05,
#  'category:user bs': 5.281689695589627e-05,
#  'ishy bilady': 5.281689695589627e-05,
#  'robert kubica': 5.281689695589627e-05,
#  'florida panhandle': 5.281689695589627e-05,
#  'helarctos malayanus': 5.281689695589627e-05,
#  'category:milan': 5.281689695589627e-05,
#  'template:hun': 5.281689695589627e-05,
#  'ishmael': 5.281689695589627e-05,
#  'the hundred years war': 5.281689695589627e-05,
#  'brown v. board of education of topeka, kansas': 5.281689695589627e-05,
#  'category:vines': 5.281689695589627e-05,
#  'category:1755 deaths': 5.281689695589627e-05,
#  'axis powers': 5.281689695589627e-05,
#  'maximilien de robespierre': 5.281689695589627e-05,
#  'tarascon-sur-rhne': 5.281689695589627e-05,
#  'los angeles kings': 5.281689695589627e-05,
#  'philosopher': 0.0019962112188998786,
#  'paper reed': 5.281689695589627e-05,
#  'category:g8': 5.281689695589627e-05,
#  "sir david's long-beaked echidna": 5.281689695589627e-05,
#  'carpenter': 0.00014739471935184281,
#  'ww ii': 5.281689695589627e-05,
#  '1088': 8.749656484077858e-05,
#  'schrdingers cat': 5.281689695589627e-05,
#  'stepchildren': 5.281689695589627e-05,
#  'category:380s': 5.281689695589627e-05,
#  'tv tokyo': 5.281689695589627e-05,
#  'atp': 5.281689695589627e-05,
#  '1970 formula one season': 5.281689695589627e-05,
#  'x rays': 5.281689695589627e-05,
#  'pakenham railway line, melbourne': 5.281689695589627e-05,
#  'category:indo-european languages': 5.281689695589627e-05,
#  'nile': 5.281689695589627e-05,
#  'derek taylor': 5.281689695589627e-05,
#  'diabetes': 0.00036286149851169126,
#  'hryvnia': 5.281689695589627e-05,
#  'lb croydon': 5.281689695589627e-05,
#  'sanjaya malakar': 5.281689695589627e-05,
#  'template:uslargestcities': 5.281689695589627e-05,
#  'immigrant': 0.0004191250039743715,
#  'category:600s bc deaths': 5.281689695589627e-05,
#  'brown hyena': 5.281689695589627e-05,
#  'southeast asia': 5.281689695589627e-05,
#  'canefield fever': 5.281689695589627e-05,
#  "queen anne's revenge": 5.281689695589627e-05,
#  'saxony': 5.281689695589627e-05,
#  'schnapps': 5.281689695589627e-05,
#  'category:1923': 5.281689695589627e-05,
#  'jurisdiction': 0.00012760303210934302,
#  'virtues of harmony': 5.281689695589627e-05,
#  'template:fra': 5.281689695589627e-05,
#  'category:frogs': 5.281689695589627e-05,
#  '1707': 0.00010339430320186403,
#  'brown dwarf': 5.281689695589627e-05,
#  '1,000,000': 5.281689695589627e-05,
#  'lira da braccio': 5.281689695589627e-05,
#  'category:chilean people': 5.281689695589627e-05,
#  'history of japan': 5.281689695589627e-05,
#  'category:1005': 5.281689695589627e-05,
#  'template:country data mexico': 5.281689695589627e-05,
#  nan: 5.281689695589627e-05,
#  'arcade (architecture)': 5.281689695589627e-05,
#  'wrocaw': 5.281689695589627e-05,
#  'category:1996': 5.281689695589627e-05,
#  'template:saf': 5.281689695589627e-05,
#  'category:user he-3': 5.281689695589627e-05,
#  'olivia newton-john': 5.281689695589627e-05,
#  'uga': 5.281689695589627e-05,
#  'ming dynasty': 5.281689695589627e-05,
#  'malaysia': 5.281689695589627e-05,
#  'schleswig-holstein': 5.281689695589627e-05,
#  'template:pronounced': 5.281689695589627e-05,
#  'category:1590s': 5.281689695589627e-05,
#  'colossus of rhodes': 5.281689695589627e-05,
#  'bra': 8.284160247841898e-05,
#  '10 june': 5.281689695589627e-05,
#  'hand': 0.0008197382554215028,
#  'aesop': 5.281689695589627e-05,
#  'rhein': 5.281689695589627e-05,
#  'himeji-j': 5.281689695589627e-05,
#  'psyche': 5.281689695589627e-05,
#  'vlerenga fotball': 5.281689695589627e-05,
#  'template:flatlist': 5.281689695589627e-05,
#  'category:coordinate systems': 5.281689695589627e-05,
#  'second indochinese war': 5.281689695589627e-05,
#  'frances folsom cleveland': 5.281689695589627e-05,
#  'abdullah calan': 5.281689695589627e-05,
#  'united states customary units': 5.281689695589627e-05,
#  'battle of princeton': 5.281689695589627e-05,
#  'courthouse': 0.0006024875463903212,
#  'moses of chorene': 5.281689695589627e-05,
#  'category:cities in maryland': 5.281689695589627e-05,
#  'template:solstice-equinox': 5.281689695589627e-05,
#  'arizona coyotes': 5.281689695589627e-05,
#  'category:1757 deaths': 5.281689695589627e-05,
#  "it's a wonderful life": 5.281689695589627e-05,
#  'leo delibes': 5.281689695589627e-05,
#  'template:user hess-2': 5.281689695589627e-05,
#  'engines': 5.281689695589627e-05,
#  'category:2010s': 5.281689695589627e-05,
#  'gram (mythology)': 5.281689695589627e-05,
#  '2004 redfern riots': 5.281689695589627e-05,
#  'ian fleming': 5.281689695589627e-05,
#  'soviet-afghan war': 5.281689695589627e-05,
#  'tinyirc': 5.281689695589627e-05,
#  'aquaculture': 0.00014934780035829432,
#  'stocking': 5.403038045240479e-05,
#  'omer': 7.53354260977883e-05,
#  'danielle panabaker': 5.281689695589627e-05,
#  'electric guitar': 0.0003859584962274302,
#  'raan': 5.281689695589627e-05,
#  'nucleobase': 5.426970528763124e-05,
#  'great depression': 5.281689695589627e-05,
#  'civil rights': 0.00013692657820731034,
#  'category:music theorists': 5.281689695589627e-05,
#  'the secret of monkey island': 5.281689695589627e-05,
#  '23 may': 5.281689695589627e-05,
#  'american sign language': 5.281689695589627e-05,
#  'alternative medicine': 5.281689695589627e-05,
#  'millipede': 5.281689695589627e-05,
#  'template:ina': 5.281689695589627e-05,
#  'gustavo adolfo bcquer': 5.281689695589627e-05,
#  'flux (disambiguation)': 5.281689695589627e-05,
#  'category:1030': 5.281689695589627e-05,
#  'template:qd-empty': 5.281689695589627e-05,
#  'category:1726 births': 5.281689695589627e-05,
#  'yoga': 0.0001205144608276011,
#  'meriadoc brandybuck': 5.281689695589627e-05,
#  'tissue': 0.00015099588881901322,
#  'carriage': 0.00014230933959417344,
#  'nazism and homosexuality': 5.281689695589627e-05,
#  'windsurfing': 5.281689695589627e-05,
#  'harmonica': 0.0006773320746317242,
#  'mercury (planet)': 5.281689695589627e-05,
#  'john cleese': 5.281689695589627e-05,
#  'sunscreen': 5.281689695589627e-05,
#  'light globe': 5.281689695589627e-05,
#  'edith roosevelt': 5.281689695589627e-05,
#  'sydney opera house': 5.281689695589627e-05,
#  'huo qubing': 5.281689695589627e-05,
#  'category:1880': 5.281689695589627e-05,
#  'danae': 5.281689695589627e-05,
#  '1546': 0.0002855662549705617,
#  'royal botanic gardens, kew': 5.281689695589627e-05,
#  'square kilometer': 5.281689695589627e-05,
#  'august 2': 5.281689695589627e-05,
#  'sir arthur conan doyle': 5.281689695589627e-05,
#  'armenian diaspora': 5.281689695589627e-05,
#  '21 march': 5.281689695589627e-05,
#  'islington': 5.281689695589627e-05,
#  'single celled organism': 5.281689695589627e-05,
#  'neuchatel': 5.281689695589627e-05,
#  'category:education in north rhine-westphalia': 5.281689695589627e-05,
#  'democrats': 5.281689695589627e-05,
#  'bushido (rapper)': 5.281689695589627e-05,
#  'category:laboratory equipment': 5.281689695589627e-05,
#  'psycho (movie)': 5.281689695589627e-05,
#  'supertramp': 5.281689695589627e-05,
#  'microform': 5.281689695589627e-05,
#  'hyaenidae': 5.281689695589627e-05,
#  'template:afdx': 5.281689695589627e-05,
#  'tavern': 0.00011897676892029752,
#  'albany, ny': 5.281689695589627e-05,
#  'aether': 5.281689695589627e-05,
#  'matt leblanc': 5.281689695589627e-05,
#  'biennial': 5.281689695589627e-05,
#  'template:succession box': 5.281689695589627e-05,
#  'thread': 0.00022522969583161986,
#  'category:cities in denmark': 5.281689695589627e-05,
#  'forecast': 5.281689695589627e-05,
#  'william blake': 5.281689695589627e-05,
#  'template:lang-gr': 5.281689695589627e-05,
#  'fictional character': 0.0003711622632193205,
#  'san jose, california': 5.281689695589627e-05,
#  '6 (number)': 5.281689695589627e-05,
#  'list of english football teams': 5.281689695589627e-05,
#  'franz kafka': 5.281689695589627e-05,
#  '1992 los angeles riots': 5.281689695589627e-05,
#  'category:irish actors': 5.281689695589627e-05,
#  'taunton': 5.281689695589627e-05,
#  'category:presidents of iceland': 5.281689695589627e-05,
#  "list of jupiter's moons": 5.281689695589627e-05,
#  'washington d.c.': 5.281689695589627e-05,
#  'missile': 0.0003355006156204227,
#  'breinigerberg': 5.281689695589627e-05,
#  'union of european football associations': 5.281689695589627e-05,
#  'arthropoda': 5.281689695589627e-05,
#  'bishop of rome': 5.281689695589627e-05,
#  'commonwealth of the northern mariana islands': 5.281689695589627e-05,
#  'radiation pressure': 5.628128605464889e-05,
#  'aix-en-provence': 5.281689695589627e-05,
#  'babes in toyland (1961 movie)': 5.281689695589627e-05,
#  'list of oil-producing nations': 5.281689695589627e-05,
#  'synaesthesia': 5.281689695589627e-05,
#  'kbe': 5.281689695589627e-05,
#  'usobi': 5.281689695589627e-05,
#  'elle macfeast': 5.281689695589627e-05,
#  'protestant': 7.53354260977883e-05,
#  'category:people by nationality': 5.281689695589627e-05,
#  'dwight d eisenhower': 5.281689695589627e-05,
#  'colon (anatomy)': 5.281689695589627e-05,
#  'eastenders': 5.281689695589627e-05,
#  'apg ii': 5.281689695589627e-05,
#  'lip-syncing': 5.281689695589627e-05,
#  'luciano pavarotti': 5.281689695589627e-05,
#  'category:1770': 5.281689695589627e-05,
#  'tube sponge': 5.281689695589627e-05,
#  'd-day (military term)': 5.281689695589627e-05,
#  'freshwater': 0.00035204150792230224,
#  'mecklenburg-vorpommern': 5.281689695589627e-05,
#  'mediawiki:sidebar': 5.281689695589627e-05,
#  'univalve': 5.281689695589627e-05,
#  'category:1996 albums': 5.281689695589627e-05,
#  'integrated taxonomic information system': 5.281689695589627e-05,
#  'bangor, me': 5.281689695589627e-05,
#  'tibet': 5.281689695589627e-05,
#  'interpreter': 9.034777885904966e-05,
#  'category:858': 5.281689695589627e-05,
#  'st. louis': 5.281689695589627e-05,
#  'doppelgnger': 9.785395523968034e-05,
#  'pound': 5.281689695589627e-05,
#  'four noble truths': 5.281689695589627e-05,
#  'olympia, washington': 5.281689695589627e-05,
#  'kerbela': 5.281689695589627e-05,
#  'category:biology': 5.281689695589627e-05,
#  'template:cb inner end': 5.281689695589627e-05,
#  'exoskeleton': 0.00020473914652755206,
#  'sundial': 5.281689695589627e-05,
#  'slope': 7.562978595585226e-05,
#  'war communism': 5.281689695589627e-05,
#  'crown cork': 5.281689695589627e-05,
#  'sidekick': 9.935519051580647e-05,
#  'leo fender': 5.281689695589627e-05,
#  'lancelot': 5.281689695589627e-05,
#  'think quest': 5.281689695589627e-05,
#  'salahuddin ayubi': 5.281689695589627e-05,
#  'snow leopards': 5.281689695589627e-05,
#  'world cup 2006': 5.281689695589627e-05,
#  'category:explorers': 5.281689695589627e-05,
#  'royal society for the prevention of cruelty to animals': 5.281689695589627e-05,
#  'category:990s births': 5.281689695589627e-05,
#  'category:1749': 5.281689695589627e-05,
#  ...}

# %% [markdown]
# # Analysis Between Semantic Graph vs Normal Dataset for PageRank

# %%
def sort_dict(input):
    keys = list(input.keys())
    values = list(input.values())
    sorted_value_idx = np.argsort(values)
    return [keys[i] for i in sorted_value_idx[::-1]]

# %%
pr_sorted = sort_dict(pr)
pr_semantic_sorted = sort_dict(pr_semantic)

# %%
kendalltau(pr_sorted, pr_semantic_sorted)
# Out:
# SignificanceResult(statistic=-0.00866888742963993, pvalue=0.19457062578100548)

# %%
pr_semantic_sorted[:10]
# Out:
# ['wikipedia:manual of style',
#  'australia',
#  'arctic',
#  'manhattan',
#  'city',
#  'racial segregation',
#  'philippines',
#  'history of japan',
#  "st. peter's basilica",
#  'albert einstein']

# %%
pr_sorted[:10]
# Out:
# ['movie',
#  'city',
#  'language',
#  'country',
#  'newspaper',
#  'sound',
#  'news',
#  'oxygen',
#  'mammal',
#  'mathematics']
